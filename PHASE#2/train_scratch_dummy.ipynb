# %%
import os
import cv2
import json
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from torchvision import datasets, transforms, models
from torchvision.models import resnet50, densenet121, inception_v3, efficientnet_b0
from torchsummary import summary
from collections import OrderedDict
from tqdm import tqdm
import albumentations as A
from albumentations.pytorch import ToTensorV2
from PIL import Image
from skimage.io import imread
from skimage.transform import resize
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt
import numpy as np
import torch
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix
from torch.nn.functional import softmax
import seaborn as sns
import wandb
import torch.nn.functional as F
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ubuntu/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# /home/ubuntu/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
BATCH_SIZE = 4

# %%
# Define the directories for training, validation, and test sets
train_dir = './data_split/train'
val_dir = './data_split/val'
test_dir = './data_split/test'

# Print the number of images in each dataset and class Few, Many, None
print('Train:')
print('Few:', len(os.listdir(os.path.join(train_dir, 'Few'))))
print('Many:', len(os.listdir(os.path.join(train_dir, 'Many'))))
print('None:', len(os.listdir(os.path.join(train_dir, 'None'))))

print('Val:')
print('Val Few:', len(os.listdir(os.path.join(val_dir, 'Few'))))
print('Val Many:', len(os.listdir(os.path.join(val_dir, 'Many'))))
print('Val None:', len(os.listdir(os.path.join(val_dir, 'None'))))

print('Test:')
print('Test Few:', len(os.listdir(os.path.join(test_dir, 'Few'))))
print('Test Many:', len(os.listdir(os.path.join(test_dir, 'Many'))))
print('Test None:', len(os.listdir(os.path.join(test_dir, 'None'))))
# Out:
# Train:
# Few: 3444
# Many: 1302
# None: 3258
# Val:
# Val Few: 1148
# Val Many: 21
# Val None: 181
# Test:
# Test Few: 1148
# Test Many: 21
# Test None: 182

# %%
class AugmentedDataset(Dataset):
    def __init__(self, root_dir, transform=None, train=False):
        self.dataset = datasets.ImageFolder(root_dir)
        self.transform = transform
        self.train = train
        self.classes = self.dataset.classes
        self.class_to_idx = self.dataset.class_to_idx
        
        self.augment_classes = ['None', 'Many']
        self.augment_indices = [self.class_to_idx[cls] for cls in self.augment_classes if cls in self.class_to_idx]
        
        # Count samples per class
        self.class_counts = [0] * len(self.classes)
        for _, label in self.dataset.samples:
            self.class_counts[label] += 1
        
        # Calculate class weights once
        total_samples = sum(self.class_counts)
        self.class_weights = [total_samples / (len(self.class_counts) * count) for count in self.class_counts]
        
        if self.train:
            self.train_augs = A.Compose([
                A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.5),  # Reduced limits
                A.GaussNoise(var_limit=(5.0, 20.0), p=0.3),  # Reduced upper var_limit
                A.ShiftScaleRotate(shift_limit=0.03, scale_limit=0.1, rotate_limit=10, p=0.5),])

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        img, label = self.dataset[idx]
        
        if self.train and label in self.augment_indices:
            img_np = np.array(img)
            augmented = self.train_augs(image=img_np)
            img_np = augmented['image']
            img = Image.fromarray(img_np)
        
        if self.transform:
            img = self.transform(img)
        
        return img, label

    def get_sample_weights(self):
        return [self.class_weights[label] for _, label in self.dataset.samples]

# %%
def create_weighted_sampler(dataset):
    sample_weights = dataset.get_sample_weights()
    return WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

# Define your transformations
transform = transforms.Compose([
    transforms.Resize((512, 512)),
    transforms.ToTensor()
])

# Create datasets
train_dataset = AugmentedDataset(train_dir, transform=transform, train=True)
val_dataset = AugmentedDataset(val_dir, transform=transform, train=False)
test_dataset = AugmentedDataset(test_dir, transform=transform, train=False)

# Create samplers
train_sampler = create_weighted_sampler(train_dataset)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, sampler=train_sampler)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

# %%
# Function to get images of a specific label
def get_images_by_label(dataloader, label, num_images=1):
    images = []
    labels = []
    for batch_images, batch_labels in dataloader:
        for img, lbl in zip(batch_images, batch_labels):
            if lbl == label:
                images.append(img)
                labels.append(lbl)
                if len(images) >= num_images:
                    return images, labels
    return images, labels

# Example usage: Get 5 images of label 0
label_to_display = 2
num_images_to_display = 5
images, labels = get_images_by_label(train_loader, label_to_display, num_images_to_display)

# Display the images
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))
for i, (img, lbl) in enumerate(zip(images, labels)):
    axes[i].imshow(img.permute(1, 2, 0))
    axes[i].set_title(f'Label: {lbl}')
    axes[i].axis('off')
plt.show()

# %%
num_class = len(train_loader.dataset.classes)
print(num_class)
print(train_loader.dataset.classes)
# Out:
# 3
# ['Few', 'Many', 'None']

# %%
class_weights = torch.tensor(train_dataset.class_weights, dtype=torch.float)
print(class_weights)
print(train_dataset.classes)
# Out:
# tensor([0.7747, 2.0492, 0.8189])
# ['Few', 'Many', 'None']

# %%
for batch in train_loader:
    print(batch[1])
    break
# Out:
# tensor([0, 2, 0, 0])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score

def calculate_metrics(y_true, y_pred, y_prob):
    cm = confusion_matrix(y_true, y_pred)
    
    # Calculate metrics for each class
    metrics = []
    sensitivities = []
    specificities = []
    
    for i in range(len(cm)):
        TP = cm[i, i]
        FP = cm[:, i].sum() - TP
        FN = cm[i, :].sum() - TP
        TN = cm.sum() - TP - FP - FN
        
        sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
        specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
        
        sensitivities.append(sensitivity)
        specificities.append(specificity)
        
        metrics.append({
            'sensitivity': sensitivity,
            'specificity': specificity
        })
    
    # Calculate overall accuracy
    accuracy = accuracy_score(y_true, y_pred)
    
    # Calculate ROC-AUC
    auc = roc_auc_score(y_true, y_prob, multi_class='ovr', average='weighted')
    
    # Calculate averaged sensitivity and specificity
    avg_sensitivity = sum(sensitivities) / len(sensitivities) if sensitivities else 0
    avg_specificity = sum(specificities) / len(specificities) if specificities else 0
    
    return accuracy, metrics, auc, cm, avg_sensitivity, avg_specificity

def plot_confusion_matrix(cm, class_names, epoch_num=0, model_name='model'):
    plt.figure(figsize=(10,8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.savefig(f'confusion_matrix_{model_name}_epoch{epoch_num}.png')
    plt.close()

def custom_log(metrics, model_name, log_dir='logs'):
    if not os.path.exists(log_dir):
        os.makedirs(log_dir)
    log_file = f'{log_dir}/{model_name}_metrics_log.json'
    with open(log_file, 'a') as f:
        f.write(json.dumps(metrics) + '\n')

# %%
def train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=1, device='cuda', model_name='model'):
    wandb.init(project="Hepatocyte Ballooning Detection", name=f"RadImageNet {model_name}")
    print(f'Training {model_name} for {num_epochs} epochs')
    min_valid_loss = np.inf
    best_metrics = {}
    class_names = ['None', 'Few', 'Many']
    
    for e in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds, train_labels = [], []

        for i_batch, batch in enumerate(train_loader):
            data, labels = batch[0].to(device, dtype=torch.float), batch[1].to(device)
            
            optimizer.zero_grad()
            outputs = model(data)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            train_preds.extend(preds.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        # Validation phase
        model.eval()
        valid_loss = 0.0
        val_preds, val_labels, val_probs = [], [], []

        with torch.no_grad():
            for i_batch, batch in enumerate(val_loader):
                data, labels = batch[0].to(device, dtype=torch.float), batch[1].to(device)
                
                outputs = model(data)
                loss = criterion(outputs, labels)
                valid_loss += loss.item() * data.size(0)

                probs = F.softmax(outputs, dim=1)
                _, preds = torch.max(outputs, 1)
                val_preds.extend(preds.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())
                val_probs.extend(probs.cpu().numpy())

        # Calculate metrics
        val_accuracy, val_class_metrics, val_auc, val_cm, avg_sensitivity, avg_specificity = calculate_metrics(val_labels, val_preds, val_probs)

        print(f'Epoch {e+1}')
        val_loss = valid_loss / len(val_loader)
        train_loss /= len(train_loader)
        print(f'Training Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}')
        print(f'Validation Accuracy: {val_accuracy:.4f}')
        print(f'Validation AUC: {val_auc:.4f}')
        print(f'Averaged Sensitivity: {avg_sensitivity:.4f}, Averaged Specificity: {avg_specificity:.4f}')
        for i, metrics in enumerate(val_class_metrics):
            print(f'Class {class_names[i]} - Sensitivity: {metrics["sensitivity"]:.4f}, Specificity: {metrics["specificity"]:.4f}')

        # Log metrics to wandb and custom logger
        metrics = {
            'epoch': e + 1,
            'train_loss': train_loss,
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'val_auc': val_auc,
            'avg_sensitivity': avg_sensitivity,
            'avg_specificity': avg_specificity,
            **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(val_class_metrics)},
            **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(val_class_metrics)}
        }

        # Log to wandb
        wandb.log(metrics)

        # Log to custom logger
        custom_log(metrics, model_name)

        # Save the best model
        if min_valid_loss > val_loss:
            print(f'Validation Loss Decreased({min_valid_loss:.6f}--->{val_loss:.6f}) \t Saving The Model')
            min_valid_loss = val_loss
            best_metrics = {
                'val_loss': val_loss,
                'val_accuracy': val_accuracy,
                'val_auc': val_auc,
                'val_class_metrics': val_class_metrics,
                'val_confusion_matrix': val_cm,
                'avg_sensitivity': avg_sensitivity,
                'avg_specificity': avg_specificity
            }
            torch.save(model.state_dict(), f'best_{model_name}.pth')
            
            # Plot confusion matrix for the best model
            plot_confusion_matrix(val_cm, class_names, e, model_name)

    print("Best Validation Metrics:")
    print(f"Accuracy: {best_metrics['val_accuracy']:.4f}")
    print(f"AUC: {best_metrics['val_auc']:.4f}")
    print(f'Averaged Sensitivity: {best_metrics["avg_sensitivity"]:.4f}, Averaged Specificity: {best_metrics["avg_specificity"]:.4f}')
    for i, metrics in enumerate(best_metrics['val_class_metrics']):
        print(f'Class {class_names[i]} - Sensitivity: {metrics["sensitivity"]:.4f}, Specificity: {metrics["specificity"]:.4f}')
    wandb.finish()

    return model, best_metrics

# %%
class Classifier(nn.Module):
    def __init__(self, num_class, in_features=2048):
        super().__init__()
        self.drop_out = nn.Dropout()
        self.linear = nn.Linear(in_features, num_class)

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.drop_out(x)
        x = self.linear(x)
        #x = torch.softmax(x, dim=-1)
        return x


class ResNetBackbone(nn.Module):
    def __init__(self, path, num_classes):
        super().__init__()
        resnet = resnet50(weights=None)
        self.backbone = nn.Sequential(*list(resnet.children())[:-1])
        
        state_dict = torch.load(path)
        new_state_dict = {}
        for k, v in state_dict.items():
            new_state_dict[k[9:]] = v

        print(self.backbone.load_state_dict(new_state_dict))  # <All keys matched successfully>
        
        self.classifier = Classifier(num_classes)

    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x
    

class DenseNetBackbone(nn.Module):
    def __init__(self, path, num_classes):
        super().__init__()
        base_model = densenet121(weights=None)
        encoder_layers = list(base_model.children())
        self.backbone = nn.Sequential(*encoder_layers[:-1])
        
        state_dict = torch.load(path)
        new_state_dict = {}
        for k, v in state_dict.items():
            new_state_dict[k[9:]] = v

        print(self.backbone.load_state_dict(new_state_dict))  # <All keys matched successfully>
        
        self.classifier = Classifier(num_classes, in_features=1024)
                        
    def forward(self, x):
        x = self.backbone(x)
        x = nn.AdaptiveAvgPool2d((1, 1))(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x
    
class InceptionBackbone(nn.Module):
    def __init__(self, path, num_classes):
        super().__init__()
        base_model = inception_v3(weights=None, aux_logits=False)
        encoder_layers = list(base_model.children())
        self.backbone = nn.Sequential(*encoder_layers[:-1])
        
        state_dict = torch.load(path)
        new_state_dict = {}
        for k, v in state_dict.items():
            new_state_dict[k[9:]] = v

        print(self.backbone.load_state_dict(new_state_dict))  # <All keys matched successfully>
        
        self.classifier = Classifier(num_classes)
                        
    def forward(self, x):
        x = self.backbone(x)
        x = self.classifier(x)
        return x

# %%
models = os.listdir('models')
print(models)
# Out:
# ['DenseNet121.pt', 'ResNet50.pt', 'InceptionV3.pt']

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# for model_name in models:
#     if model_name == 'ResNet50.pt':
#         model = ResNetBackbone(path=f'models/{model_name}', num_classes=num_class).to(device)
#     elif model_name == 'DenseNet121.pt':
#         model = DenseNetBackbone(path=f'models/{model_name}', num_classes=num_class).to(device)
#     elif model_name == 'InceptionV3.pt':
#         model = InceptionBackbone(path=f'models/{model_name}', num_classes=num_class).to(device)
#     else:
#         continue

model = efficientnet_b0(weights=None)
model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_class)
model = model.to(device)
model_name = 'EfficientNetB0'

criterion = nn.CrossEntropyLoss(weight=class_weights.to(device))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
best_model, best_metrics = train_model(model, criterion, optimizer, train_loader, val_loader, num_epochs=30, device=device, model_name=model_name)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········
# wandb: Appending key for api.wandb.ai to your netrc file: /home/ubuntu/.netrc
# Tracking run with wandb version 0.17.4
# Run data is saved locally in <code>/home/ubuntu/wandb/run-20240714_210047-a0w7w0mt</code>
# Syncing run <strong><a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection/runs/a0w7w0mt' target="_blank">RadImageNet EfficientNetB0</a></strong> to <a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection' target="_blank">https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection</a>
#  View run at <a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection/runs/a0w7w0mt' target="_blank">https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection/runs/a0w7w0mt</a>
# Training EfficientNetB0 for 30 epochs
# Epoch 1
# Training Loss: 0.8627, Validation Loss: 2.8076
# Validation Accuracy: 0.7467
# Validation AUC: 0.5017
# Averaged Sensitivity: 0.3659, Averaged Specificity: 0.6678
# Class None - Sensitivity: 0.8685, Specificity: 0.1337
# Class Few - Sensitivity: 0.1905, Specificity: 0.9082
# Class Many - Sensitivity: 0.0387, Specificity: 0.9615
# Validation Loss Decreased(inf--->2.807581) 	 Saving The Model
# Epoch 2
# Training Loss: 0.7506, Validation Loss: 2.4923
# Validation Accuracy: 0.7733
# Validation AUC: 0.5396
# Averaged Sensitivity: 0.3763, Averaged Specificity: 0.6695
# Class None - Sensitivity: 0.8998, Specificity: 0.1089
# Class Few - Sensitivity: 0.1905, Specificity: 0.9466
# Class Many - Sensitivity: 0.0387, Specificity: 0.9530
# Validation Loss Decreased(2.807581--->2.492285) 	 Saving The Model
# Epoch 3
# Training Loss: 0.6654, Validation Loss: 2.7128
# Validation Accuracy: 0.7178
# Validation AUC: 0.5899
# Averaged Sensitivity: 0.5009, Averaged Specificity: 0.7032
# Class None - Sensitivity: 0.8153, Specificity: 0.3020
# Class Few - Sensitivity: 0.5714, Specificity: 0.9059
# Class Many - Sensitivity: 0.1160, Specificity: 0.9016
# Epoch 4
# Training Loss: 0.6161, Validation Loss: 2.7027
# Validation Accuracy: 0.7385
# Validation AUC: 0.5634
# Averaged Sensitivity: 0.4732, Averaged Specificity: 0.6825
# Class None - Sensitivity: 0.8441, Specificity: 0.2030
# Class Few - Sensitivity: 0.4762, Specificity: 0.9353
# Class Many - Sensitivity: 0.0994, Specificity: 0.9093
# Epoch 5
# Training Loss: 0.5262, Validation Loss: 4.5520
# Validation Accuracy: 0.4719
# Validation AUC: 0.5948
# Averaged Sensitivity: 0.5723, Averaged Specificity: 0.7220
# Class None - Sensitivity: 0.4634, Specificity: 0.7079
# Class Few - Sensitivity: 0.7619, Specificity: 0.8728
# Class Many - Sensitivity: 0.4917, Specificity: 0.5851
# Epoch 6
# Training Loss: 0.4920, Validation Loss: 2.7565
# Validation Accuracy: 0.7430
# Validation AUC: 0.5711
# Averaged Sensitivity: 0.4953, Averaged Specificity: 0.6849
# Class None - Sensitivity: 0.8537, Specificity: 0.2030
# Class Few - Sensitivity: 0.5714, Specificity: 0.9210
# Class Many - Sensitivity: 0.0608, Specificity: 0.9307
# Epoch 7
# Training Loss: 0.4316, Validation Loss: 2.8970
# Validation Accuracy: 0.6807
# Validation AUC: 0.5815
# Averaged Sensitivity: 0.5283, Averaged Specificity: 0.7006
# Class None - Sensitivity: 0.7483, Specificity: 0.3515
# Class Few - Sensitivity: 0.5714, Specificity: 0.9488
# Class Many - Sensitivity: 0.2652, Specificity: 0.8015
# Epoch 8
# Training Loss: 0.4131, Validation Loss: 2.5192
# Validation Accuracy: 0.7333
# Validation AUC: 0.6083
# Averaged Sensitivity: 0.4975, Averaged Specificity: 0.7034
# Class None - Sensitivity: 0.8153, Specificity: 0.2921
# Class Few - Sensitivity: 0.4286, Specificity: 0.9722
# Class Many - Sensitivity: 0.2486, Specificity: 0.8460
# Epoch 9
# Training Loss: 0.3738, Validation Loss: 2.4798
# Validation Accuracy: 0.8244
# Validation AUC: 0.6065
# Averaged Sensitivity: 0.4088, Averaged Specificity: 0.6753
# Class None - Sensitivity: 0.9608, Specificity: 0.0644
# Class Few - Sensitivity: 0.2381, Specificity: 0.9812
# Class Many - Sensitivity: 0.0276, Specificity: 0.9803
# Validation Loss Decreased(2.492285--->2.479767) 	 Saving The Model
# Epoch 10
# Training Loss: 0.3390, Validation Loss: 3.5527
# Validation Accuracy: 0.5970
# Validation AUC: 0.5925
# Averaged Sensitivity: 0.5219, Averaged Specificity: 0.7016
# Class None - Sensitivity: 0.6350, Specificity: 0.4653
# Class Few - Sensitivity: 0.5714, Specificity: 0.9082
# Class Many - Sensitivity: 0.3591, Specificity: 0.7314
# Epoch 11
# Training Loss: 0.3091, Validation Loss: 2.7079
# Validation Accuracy: 0.7385
# Validation AUC: 0.6024
# Averaged Sensitivity: 0.5355, Averaged Specificity: 0.7026
# Class None - Sensitivity: 0.8328, Specificity: 0.2772
# Class Few - Sensitivity: 0.6190, Specificity: 0.9451
# Class Many - Sensitivity: 0.1547, Specificity: 0.8854
# Epoch 12
# Training Loss: 0.2917, Validation Loss: 2.3611
# Validation Accuracy: 0.8207
# Validation AUC: 0.6007
# Averaged Sensitivity: 0.3809, Averaged Specificity: 0.6724
# Class None - Sensitivity: 0.9556, Specificity: 0.0594
# Class Few - Sensitivity: 0.1429, Specificity: 0.9834
# Class Many - Sensitivity: 0.0442, Specificity: 0.9743
# Validation Loss Decreased(2.479767--->2.361108) 	 Saving The Model
# Epoch 13
# Training Loss: 0.2622, Validation Loss: 2.1042
# Validation Accuracy: 0.7978
# Validation AUC: 0.6345
# Averaged Sensitivity: 0.4840, Averaged Specificity: 0.6908
# Class None - Sensitivity: 0.9129, Specificity: 0.1584
# Class Few - Sensitivity: 0.4286, Specificity: 0.9850
# Class Many - Sensitivity: 0.1105, Specificity: 0.9290
# Validation Loss Decreased(2.361108--->2.104246) 	 Saving The Model
# Epoch 14
# Training Loss: 0.2510, Validation Loss: 2.3173
# Validation Accuracy: 0.7585
# Validation AUC: 0.6405
# Averaged Sensitivity: 0.4684, Averaged Specificity: 0.7149
# Class None - Sensitivity: 0.8432, Specificity: 0.3020
# Class Few - Sensitivity: 0.2857, Specificity: 0.9932
# Class Many - Sensitivity: 0.2762, Specificity: 0.8494
# Epoch 15
# Training Loss: 0.2276, Validation Loss: 2.0014
# Validation Accuracy: 0.8111
# Validation AUC: 0.6204
# Averaged Sensitivity: 0.4955, Averaged Specificity: 0.6920
# Class None - Sensitivity: 0.9329, Specificity: 0.1436
# Class Few - Sensitivity: 0.4762, Specificity: 0.9819
# Class Many - Sensitivity: 0.0773, Specificity: 0.9504
# Validation Loss Decreased(2.104246--->2.001415) 	 Saving The Model
# Epoch 16
# Training Loss: 0.2285, Validation Loss: 3.4645
# Validation Accuracy: 0.6022
# Validation AUC: 0.6255
# Averaged Sensitivity: 0.5877, Averaged Specificity: 0.7124
# Class None - Sensitivity: 0.6289, Specificity: 0.5050
# Class Few - Sensitivity: 0.7143, Specificity: 0.9556
# Class Many - Sensitivity: 0.4199, Specificity: 0.6766
# Epoch 17
# Training Loss: 0.2052, Validation Loss: 2.2081
# Validation Accuracy: 0.8067
# Validation AUC: 0.6504
# Averaged Sensitivity: 0.4735, Averaged Specificity: 0.6952
# Class None - Sensitivity: 0.9312, Specificity: 0.1584
# Class Few - Sensitivity: 0.4286, Specificity: 0.9631
# Class Many - Sensitivity: 0.0608, Specificity: 0.9641
# Epoch 18
# Training Loss: 0.1969, Validation Loss: 2.1930
# Validation Accuracy: 0.8267
# Validation AUC: 0.6191
# Averaged Sensitivity: 0.4596, Averaged Specificity: 0.6784
# Class None - Sensitivity: 0.9591, Specificity: 0.0743
# Class Few - Sensitivity: 0.3810, Specificity: 0.9910
# Class Many - Sensitivity: 0.0387, Specificity: 0.9701
# Epoch 19
# Training Loss: 0.1864, Validation Loss: 2.0451
# Validation Accuracy: 0.8163
# Validation AUC: 0.6168
# Averaged Sensitivity: 0.4165, Averaged Specificity: 0.6784
# Class None - Sensitivity: 0.9451, Specificity: 0.0891
# Class Few - Sensitivity: 0.2381, Specificity: 0.9947
# Class Many - Sensitivity: 0.0663, Specificity: 0.9512
# Epoch 20
# Training Loss: 0.1850, Validation Loss: 2.4440
# Validation Accuracy: 0.7615
# Validation AUC: 0.6241
# Averaged Sensitivity: 0.4774, Averaged Specificity: 0.6945
# Class None - Sensitivity: 0.8580, Specificity: 0.2228
# Class Few - Sensitivity: 0.3810, Specificity: 0.9865
# Class Many - Sensitivity: 0.1934, Specificity: 0.8743
# Epoch 21
# Training Loss: 0.1715, Validation Loss: 2.4050
# Validation Accuracy: 0.7785
# Validation AUC: 0.5570
# Averaged Sensitivity: 0.4468, Averaged Specificity: 0.6954
# Class None - Sensitivity: 0.8833, Specificity: 0.2030
# Class Few - Sensitivity: 0.2857, Specificity: 0.9917
# Class Many - Sensitivity: 0.1713, Specificity: 0.8914
# Epoch 22
# Training Loss: 0.1730, Validation Loss: 2.4525
# Validation Accuracy: 0.7911
# Validation AUC: 0.6445
# Averaged Sensitivity: 0.5687, Averaged Specificity: 0.7038
# Class None - Sensitivity: 0.9033, Specificity: 0.2079
# Class Few - Sensitivity: 0.7143, Specificity: 0.9421
# Class Many - Sensitivity: 0.0884, Specificity: 0.9615
# Epoch 23
# Training Loss: 0.1650, Validation Loss: 1.9691
# Validation Accuracy: 0.8207
# Validation AUC: 0.5890
# Averaged Sensitivity: 0.4946, Averaged Specificity: 0.6914
# Class None - Sensitivity: 0.9469, Specificity: 0.1287
# Class Few - Sensitivity: 0.4762, Specificity: 0.9857
# Class Many - Sensitivity: 0.0608, Specificity: 0.9598
# Validation Loss Decreased(2.001415--->1.969149) 	 Saving The Model
# Epoch 24
# Training Loss: 0.1528, Validation Loss: 4.9174
# Validation Accuracy: 0.5533
# Validation AUC: 0.6377
# Averaged Sensitivity: 0.5683, Averaged Specificity: 0.7349
# Class None - Sensitivity: 0.5401, Specificity: 0.6584
# Class Few - Sensitivity: 0.5238, Specificity: 0.9767
# Class Many - Sensitivity: 0.6409, Specificity: 0.5697
# Epoch 25
# Training Loss: 0.1438, Validation Loss: 2.1794
# Validation Accuracy: 0.8015
# Validation AUC: 0.6694
# Averaged Sensitivity: 0.5353, Averaged Specificity: 0.7034
# Class None - Sensitivity: 0.9129, Specificity: 0.1980
# Class Few - Sensitivity: 0.5714, Specificity: 0.9797
# Class Many - Sensitivity: 0.1215, Specificity: 0.9324
# Epoch 26
# Training Loss: 0.1398, Validation Loss: 2.1748
# Validation Accuracy: 0.7985
# Validation AUC: 0.6362
# Averaged Sensitivity: 0.4593, Averaged Specificity: 0.6909
# Class None - Sensitivity: 0.9120, Specificity: 0.1584
# Class Few - Sensitivity: 0.3333, Specificity: 0.9895
# Class Many - Sensitivity: 0.1326, Specificity: 0.9247
# Epoch 27
# Training Loss: 0.1372, Validation Loss: 2.2833
# Validation Accuracy: 0.7941
# Validation AUC: 0.6720
# Averaged Sensitivity: 0.5947, Averaged Specificity: 0.7137
# Class None - Sensitivity: 0.9007, Specificity: 0.2426
# Class Few - Sensitivity: 0.7619, Specificity: 0.9594
# Class Many - Sensitivity: 0.1215, Specificity: 0.9393
# Epoch 28
# Training Loss: 0.1317, Validation Loss: 1.9102
# Validation Accuracy: 0.8363
# Validation AUC: 0.6318
# Averaged Sensitivity: 0.4914, Averaged Specificity: 0.6835
# Class None - Sensitivity: 0.9704, Specificity: 0.0792
# Class Few - Sensitivity: 0.4762, Specificity: 0.9910
# Class Many - Sensitivity: 0.0276, Specificity: 0.9803
# Validation Loss Decreased(1.969149--->1.910221) 	 Saving The Model
# Epoch 29
# Training Loss: 0.1407, Validation Loss: 2.3496
# Validation Accuracy: 0.8385
# Validation AUC: 0.6395
# Averaged Sensitivity: 0.4548, Averaged Specificity: 0.6868
# Class None - Sensitivity: 0.9704, Specificity: 0.0891
# Class Few - Sensitivity: 0.3333, Specificity: 0.9977
# Class Many - Sensitivity: 0.0608, Specificity: 0.9735
# Epoch 30
# Training Loss: 0.1328, Validation Loss: 2.2951
# Validation Accuracy: 0.7822
# Validation AUC: 0.6159
# Averaged Sensitivity: 0.4919, Averaged Specificity: 0.6969
# Class None - Sensitivity: 0.8868, Specificity: 0.2030
# Class Few - Sensitivity: 0.4286, Specificity: 0.9887
# Class Many - Sensitivity: 0.1602, Specificity: 0.8991
# Best Validation Metrics:
# Accuracy: 0.8363
# AUC: 0.6318
# Averaged Sensitivity: 0.4914, Averaged Specificity: 0.6835
# Class None - Sensitivity: 0.9704, Specificity: 0.0792
# Class Few - Sensitivity: 0.4762, Specificity: 0.9910
# Class Many - Sensitivity: 0.0276, Specificity: 0.9803
# VBox(children=(Label(value='0.021 MB of 0.021 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_sensitivity</td><td>▁▁▅▄▇▅▆▅▂▆▆▁▅▄▅█▄▄▃▄▃▇▅▇▆▄█▅▄▅</td></tr><tr><td>avg_specificity</td><td>▁▁▅▃▇▃▄▅▂▅▅▁▃▆▄▆▄▂▂▄▄▅▃█▅▃▆▃▃▄</td></tr><tr><td>class_Few_sensitivity</td><td>▂▂▆▅█▆▆▄▂▆▆▁▄▃▅▇▄▄▂▄▃▇▅▅▆▃█▅▃▄</td></tr><tr><td>class_Few_specificity</td><td>▃▅▃▅▁▄▅▇▇▃▅▇▇█▇▆▆██▇█▅▇▇▇█▆██▇</td></tr><tr><td>class_Many_sensitivity</td><td>▁▁▂▂▆▁▄▄▁▅▂▁▂▄▂▅▁▁▁▃▃▂▁█▂▂▂▁▁▃</td></tr><tr><td>class_Many_specificity</td><td>██▇▇▁▇▅▆█▄▆█▇▆▇▃███▆▆██▁▇▇▇██▇</td></tr><tr><td>class_None_sensitivity</td><td>▇▇▆▆▁▆▅▆█▃▆█▇▆▇▃▇██▆▇▇█▂▇▇▇██▇</td></tr><tr><td>class_None_specificity</td><td>▂▂▄▃█▃▄▄▁▅▃▁▂▄▂▆▂▁▁▃▃▃▂▇▂▂▃▁▁▃</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▆▇▆▆▁▆▅▆█▃▆█▇▆▇▃▇██▇▇▇█▃▇▇▇██▇</td></tr><tr><td>val_auc</td><td>▁▃▅▄▅▄▄▅▅▅▅▅▆▇▆▆▇▆▆▆▃▇▅▇█▇█▆▇▆</td></tr><tr><td>val_loss</td><td>▃▂▃▃▇▃▃▂▂▅▃▂▁▂▁▅▂▂▁▂▂▂▁█▂▂▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_sensitivity</td><td>0.49185</td></tr><tr><td>avg_specificity</td><td>0.69691</td></tr><tr><td>class_Few_sensitivity</td><td>0.42857</td></tr><tr><td>class_Few_specificity</td><td>0.98871</td></tr><tr><td>class_Many_sensitivity</td><td>0.16022</td></tr><tr><td>class_Many_specificity</td><td>0.89906</td></tr><tr><td>class_None_sensitivity</td><td>0.88676</td></tr><tr><td>class_None_specificity</td><td>0.20297</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>train_loss</td><td>0.1328</td></tr><tr><td>val_accuracy</td><td>0.78222</td></tr><tr><td>val_auc</td><td>0.61589</td></tr><tr><td>val_loss</td><td>2.29506</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">RadImageNet EfficientNetB0</strong> at: <a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection/runs/a0w7w0mt' target="_blank">https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection/runs/a0w7w0mt</a><br/> View project at: <a href='https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection' target="_blank">https://wandb.ai/samwellwatwat/Hepatocyte%20Ballooning%20Detection</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240714_210047-a0w7w0mt/logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
