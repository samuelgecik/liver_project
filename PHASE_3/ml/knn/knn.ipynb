# %%
import os
import sys
import json
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score, roc_auc_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
# Add the directory two levels up to sys.path
grandparent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.insert(0, grandparent_dir)

# Now you can import the module from the grandparent directory
try:
    from metrics import *
    print("Module 'metrics' imported successfully.")
except ModuleNotFoundError as e:
    print(f"Error: {e}")
    print("Ensure that 'metrics.py' is located in the grandparent directory.")
# Out:
# Module 'metrics' imported successfully.

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
os.makedirs('logs', exist_ok=True)
os.makedirs('figures', exist_ok=True)

# %%
def custom_scorer(y_true, y_pred):
    # If y_pred is probabilities, convert to class predictions
    if y_pred.ndim == 2:
        y_pred_class = np.argmax(y_pred, axis=1)
    else:
        y_pred_class = y_pred

    # Calculate metrics
    auc = roc_auc_score(y_true, y_pred, average='macro', multi_class='ovo')
    f1 = f1_score(y_true, y_pred_class, average='macro')
    kappa = cohen_kappa_score(y_true, y_pred_class)
    balanced_acc = balanced_accuracy_score(y_true, y_pred_class)
    
    return 0.3 * auc + 0.3 * f1 + 0.2 * kappa + 0.2 * balanced_acc

custom_score = make_scorer(custom_scorer, greater_is_better=True, needs_proba=True)
# Out:
# /home/samo/dev/liver/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
# Define the parameter grid for KNN
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11, 13, 15],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski'],
    'p': [1, 2],  # Only relevant for Minkowski metric
    'leaf_size': [10, 20, 30, 40, 50],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# Initialize the KNN classifier
knn = KNeighborsClassifier()

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=knn, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=5, p=2, weights=distance; total time=   2.0s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=5, p=2, weights=distance; total time=   2.2s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=5, p=2, weights=distance; total time=   2.6s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=5, p=2, weights=distance; total time=   2.9s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=5, p=2, weights=distance; total time=   4.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=  22.2s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=  23.4s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=  23.7s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=  25.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=2, weights=uniform; total time=  25.4s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=13, p=1, weights=distance; total time=  35.3s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=  39.3s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=  40.2s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=  39.0s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=  41.7s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=5, p=2, weights=distance; total time=  41.3s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=13, p=1, weights=distance; total time=  40.2s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  23.2s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  24.1s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=13, p=1, weights=distance; total time=  34.3s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=13, p=1, weights=distance; total time=  37.5s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=13, p=1, weights=distance; total time=  37.2s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=  23.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  27.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=  22.6s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=  21.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=  23.1s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  27.4s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  26.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=5, p=1, weights=distance; total time=  18.7s
# [CV] END algorithm=brute, leaf_size=50, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  33.0s
# [CV] END algorithm=brute, leaf_size=50, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  28.8s
# [CV] END algorithm=brute, leaf_size=50, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  28.3s
# [CV] END algorithm=brute, leaf_size=50, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  27.7s
# [CV] END algorithm=brute, leaf_size=50, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  31.6s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  27.8s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  31.3s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  30.7s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  30.9s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  30.8s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  30.9s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  31.5s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=uniform; total time=  18.1s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=uniform; total time=  20.0s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  33.2s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=uniform; total time=  21.5s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=uniform; total time=  21.4s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=uniform; total time=  21.5s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.2s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.9s
# [CV] END algorithm=brute, leaf_size=10, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  33.2s
# [CV] END algorithm=brute, leaf_size=10, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  33.9s
# [CV] END algorithm=brute, leaf_size=10, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  34.4s
# [CV] END algorithm=brute, leaf_size=10, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  33.5s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=uniform; total time=  20.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=uniform; total time=  18.9s
# [CV] END algorithm=brute, leaf_size=10, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  34.7s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  46.2s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  44.8s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=11, p=1, weights=distance; total time=  28.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=uniform; total time=  31.4s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  49.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=uniform; total time=  36.0s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  50.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=uniform; total time=  36.8s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=11, p=1, weights=distance; total time=  33.4s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=2, weights=distance; total time=  54.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=11, p=1, weights=distance; total time=  34.1s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=11, p=1, weights=distance; total time=  35.2s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   2.3s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   2.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  25.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=minkowski, n_neighbors=11, p=1, weights=distance; total time=  29.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  27.2s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   2.1s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=9, p=2, weights=uniform; total time=   2.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  25.1s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  23.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  27.9s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  35.8s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  35.7s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=  15.5s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  33.4s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  33.8s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=  16.4s
# [CV] END algorithm=auto, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  33.3s
# [CV] END algorithm=auto, leaf_size=40, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  34.0s
# [CV] END algorithm=auto, leaf_size=40, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  33.1s
# [CV] END algorithm=auto, leaf_size=40, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  35.1s
# [CV] END algorithm=auto, leaf_size=40, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  35.2s
# [CV] END algorithm=auto, leaf_size=40, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  32.9s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=  28.2s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  32.4s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  31.8s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  33.5s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=  36.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  33.9s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=5, p=2, weights=distance; total time=  35.7s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=7, p=1, weights=distance; total time=   4.0s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=7, p=1, weights=distance; total time=   3.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=7, p=1, weights=distance; total time=   3.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=7, p=1, weights=distance; total time=   4.1s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=7, p=1, weights=distance; total time=   4.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  40.6s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=  52.8s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=  53.6s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=  56.3s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time= 1.1min
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=  59.1s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=3, p=1, weights=distance; total time=  56.8s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=3, p=1, weights=distance; total time=  57.6s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=3, p=1, weights=distance; total time=  59.9s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  58.1s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=3, p=1, weights=distance; total time= 1.0min
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=3, p=1, weights=distance; total time= 1.0min
# [CV] END algorithm=ball_tree, leaf_size=50, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  49.2s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  43.7s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  42.9s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  43.6s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=   1.9s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  40.6s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  38.8s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  34.4s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  33.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=11, p=1, weights=uniform; total time=  34.8s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  35.8s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  34.7s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  35.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  17.7s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  20.3s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  21.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  16.3s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  38.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  20.5s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  34.1s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  31.2s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  32.4s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  26.1s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  29.8s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=  22.5s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  32.4s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  34.6s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  30.3s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  30.5s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=  26.6s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  30.0s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  29.8s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=  33.4s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=  34.4s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  35.0s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=3, p=1, weights=uniform; total time=  39.0s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  39.6s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  42.0s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  42.8s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  39.0s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   2.7s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   2.3s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  40.8s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   2.7s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  42.8s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   2.1s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  42.9s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  47.3s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  27.7s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  29.1s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  36.3s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  30.5s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  25.0s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=13, p=1, weights=distance; total time=  26.4s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  31.2s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  30.1s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  29.8s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  30.3s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  15.3s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=2, weights=uniform; total time=  33.1s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=   2.1s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=distance; total time=   1.9s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  16.7s
# [CV] END algorithm=brute, leaf_size=40, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  31.8s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   1.9s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   2.1s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   2.0s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=30, metric=minkowski, n_neighbors=9, p=2, weights=distance; total time=   2.0s
# [CV] END algorithm=brute, leaf_size=40, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  29.5s
# [CV] END algorithm=brute, leaf_size=40, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  28.7s
# [CV] END algorithm=brute, leaf_size=40, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  29.0s
# [CV] END algorithm=brute, leaf_size=40, metric=minkowski, n_neighbors=3, p=1, weights=distance; total time=  32.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  19.1s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  21.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  22.5s
# [CV] END algorithm=auto, leaf_size=10, metric=euclidean, n_neighbors=13, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=auto, leaf_size=10, metric=euclidean, n_neighbors=13, p=2, weights=distance; total time=   2.7s
# [CV] END algorithm=auto, leaf_size=10, metric=euclidean, n_neighbors=13, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=auto, leaf_size=10, metric=euclidean, n_neighbors=13, p=2, weights=distance; total time=   2.2s
# [CV] END algorithm=auto, leaf_size=10, metric=euclidean, n_neighbors=13, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  25.9s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  28.5s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  28.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  28.0s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=5, p=1, weights=distance; total time=  29.9s
# [CV] END algorithm=auto, leaf_size=50, metric=euclidean, n_neighbors=3, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  29.9s
# [CV] END algorithm=auto, leaf_size=50, metric=euclidean, n_neighbors=3, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=50, metric=euclidean, n_neighbors=3, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=auto, leaf_size=50, metric=euclidean, n_neighbors=3, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=auto, leaf_size=50, metric=euclidean, n_neighbors=3, p=2, weights=distance; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  29.9s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  34.8s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  28.6s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=uniform; total time=  32.3s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  29.4s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  29.9s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  27.3s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  28.8s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  28.8s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   1.5s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   1.6s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   1.5s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.1s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   1.5s
# [CV] END algorithm=brute, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=   1.5s
# [CV] END algorithm=auto, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=auto, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=distance; total time=   1.6s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.3s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.3s
# [CV] END algorithm=auto, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  27.3s
# [CV] END algorithm=auto, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=20, metric=euclidean, n_neighbors=9, p=2, weights=distance; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=uniform; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.4s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=uniform; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=40, metric=euclidean, n_neighbors=5, p=1, weights=uniform; total time=   1.6s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  27.7s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  27.8s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  31.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  17.4s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  18.4s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  18.7s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  19.1s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  29.6s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  20.1s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  33.5s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=  34.2s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=  33.9s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=  33.3s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=11, p=1, weights=distance; total time=  21.6s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=  34.6s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=11, p=1, weights=distance; total time=  23.1s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=11, p=1, weights=distance; total time=  22.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=11, p=1, weights=distance; total time=  23.9s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=7, p=1, weights=uniform; total time=   2.9s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=7, p=1, weights=uniform; total time=   3.6s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=7, p=1, weights=uniform; total time=   2.7s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=7, p=1, weights=uniform; total time=   3.2s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=11, p=1, weights=distance; total time=  26.3s
# [CV] END algorithm=brute, leaf_size=30, metric=euclidean, n_neighbors=7, p=1, weights=uniform; total time=   3.1s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  31.8s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  31.0s
# [CV] END algorithm=auto, leaf_size=10, metric=minkowski, n_neighbors=7, p=1, weights=distance; total time=  37.5s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  36.7s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  41.3s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  42.4s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=  40.2s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  44.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  45.7s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  48.7s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=  41.5s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  50.4s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  50.1s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=  44.2s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=  47.2s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  28.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  32.8s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  30.7s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  32.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=9, p=1, weights=distance; total time=  44.4s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=  30.3s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=   2.6s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=   2.1s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=   2.6s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  30.7s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=   2.1s
# [CV] END algorithm=brute, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  33.0s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  31.9s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  31.5s
# [CV] END algorithm=ball_tree, leaf_size=10, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  32.7s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  37.0s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=  18.5s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  40.5s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=  18.6s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=  21.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=  21.8s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  38.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=euclidean, n_neighbors=7, p=2, weights=distance; total time=  21.7s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  32.1s
# [CV] END algorithm=brute, leaf_size=10, metric=manhattan, n_neighbors=9, p=2, weights=uniform; total time=  36.4s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  30.2s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  30.6s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  27.8s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  28.0s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=minkowski, n_neighbors=13, p=1, weights=distance; total time=  29.1s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=  25.5s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.1s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.0s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=  26.5s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.2s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  32.5s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=  29.2s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=  28.4s
# [CV] END algorithm=kd_tree, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=uniform; total time=  27.5s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  28.5s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  30.7s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  31.0s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  31.5s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  32.0s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=  34.3s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=  34.4s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  28.9s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=  37.7s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=  37.6s
# [CV] END algorithm=auto, leaf_size=50, metric=manhattan, n_neighbors=7, p=2, weights=uniform; total time=  34.4s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  26.6s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  27.2s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  26.4s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=7, p=2, weights=uniform; total time=  23.7s
# [CV] END algorithm=brute, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  29.5s
# [CV] END algorithm=brute, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  34.5s
# [CV] END algorithm=brute, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  29.9s
# [CV] END algorithm=brute, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  30.3s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  16.3s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  16.3s
# [CV] END algorithm=brute, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=uniform; total time=  31.4s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  31.4s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  31.9s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  30.9s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  31.7s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=3, p=2, weights=uniform; total time=  31.8s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  26.2s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  29.9s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  26.3s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=13, p=1, weights=uniform; total time=  29.2s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.2s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  28.5s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  29.4s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=manhattan, n_neighbors=3, p=2, weights=distance; total time=  30.2s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=  34.1s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=  33.6s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=  42.4s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=  43.6s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  24.4s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  27.7s
# [CV] END algorithm=brute, leaf_size=50, metric=manhattan, n_neighbors=5, p=2, weights=uniform; total time=  31.9s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  26.1s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  27.8s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=9, p=1, weights=distance; total time=  27.4s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=11, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=11, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=11, p=2, weights=distance; total time=   1.8s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=11, p=2, weights=distance; total time=   1.9s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=11, p=2, weights=distance; total time=   1.7s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=  36.1s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  20.8s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=  37.0s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=  30.5s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  24.2s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  22.6s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=  31.2s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  24.7s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  24.3s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  22.8s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=brute, leaf_size=20, metric=minkowski, n_neighbors=9, p=1, weights=uniform; total time=  37.3s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.9s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.7s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  26.7s
# [CV] END algorithm=auto, leaf_size=50, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   3.4s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  30.6s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  26.4s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=euclidean, n_neighbors=3, p=2, weights=uniform; total time=  27.3s
# [CV] END algorithm=auto, leaf_size=30, metric=euclidean, n_neighbors=13, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=auto, leaf_size=30, metric=euclidean, n_neighbors=13, p=1, weights=uniform; total time=   2.2s
# [CV] END algorithm=auto, leaf_size=30, metric=euclidean, n_neighbors=13, p=1, weights=uniform; total time=   2.0s
# [CV] END algorithm=auto, leaf_size=30, metric=euclidean, n_neighbors=13, p=1, weights=uniform; total time=   2.0s
# [CV] END algorithm=auto, leaf_size=30, metric=euclidean, n_neighbors=13, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=brute, leaf_size=20, metric=euclidean, n_neighbors=3, p=1, weights=uniform; total time=   1.9s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=minkowski, n_neighbors=15, p=2, weights=distance; total time=  35.7s
# [CV] END algorithm=auto, leaf_size=20, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.0s
# [CV] END algorithm=auto, leaf_size=20, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   1.9s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=minkowski, n_neighbors=15, p=2, weights=distance; total time=  37.4s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  26.6s
# [CV] END algorithm=auto, leaf_size=20, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.4s
# [CV] END algorithm=auto, leaf_size=20, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.1s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  24.9s
# [CV] END algorithm=auto, leaf_size=20, metric=minkowski, n_neighbors=13, p=2, weights=uniform; total time=   2.2s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=minkowski, n_neighbors=15, p=2, weights=distance; total time=  36.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  25.9s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=minkowski, n_neighbors=15, p=2, weights=distance; total time=  36.9s
# [CV] END algorithm=auto, leaf_size=40, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=   2.7s
# [CV] END algorithm=auto, leaf_size=40, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=   2.1s
# [CV] END algorithm=auto, leaf_size=40, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=auto, leaf_size=40, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=   2.4s
# [CV] END algorithm=auto, leaf_size=40, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=   2.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  28.2s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=minkowski, n_neighbors=15, p=2, weights=distance; total time=  38.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=9, p=1, weights=uniform; total time=  27.4s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  39.6s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  40.5s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=13, p=2, weights=uniform; total time=  40.7s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=13, p=2, weights=uniform; total time=  41.1s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  42.0s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  42.8s
# [CV] END algorithm=ball_tree, leaf_size=40, metric=manhattan, n_neighbors=15, p=1, weights=uniform; total time=  43.6s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=13, p=2, weights=uniform; total time=  44.0s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=  42.7s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=13, p=2, weights=uniform; total time=  43.2s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=manhattan, n_neighbors=13, p=2, weights=uniform; total time=  44.7s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=  42.9s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=  31.8s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=  31.4s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=7, p=1, weights=distance; total time=  31.0s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  30.1s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=15, p=1, weights=distance; total time=  36.0s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=15, p=1, weights=distance; total time=  38.2s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  36.3s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=15, p=1, weights=distance; total time=  38.7s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=15, p=1, weights=distance; total time=  40.0s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  37.4s
# [CV] END algorithm=ball_tree, leaf_size=30, metric=euclidean, n_neighbors=15, p=1, weights=distance; total time=  39.2s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  34.8s
# [CV] END algorithm=kd_tree, leaf_size=50, metric=manhattan, n_neighbors=3, p=1, weights=distance; total time=  25.6s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  28.3s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  32.3s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  29.5s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  31.0s
# [CV] END algorithm=kd_tree, leaf_size=10, metric=euclidean, n_neighbors=11, p=2, weights=distance; total time=  31.2s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=  33.5s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=  32.8s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=  33.2s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=15, p=1, weights=uniform; total time=  27.8s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=  33.5s
# [CV] END algorithm=auto, leaf_size=10, metric=manhattan, n_neighbors=5, p=1, weights=uniform; total time=  37.1s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=15, p=1, weights=uniform; total time=  29.1s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=15, p=1, weights=uniform; total time=  32.2s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=15, p=1, weights=uniform; total time=  32.2s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=euclidean, n_neighbors=15, p=1, weights=uniform; total time=  32.7s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  34.0s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  34.4s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  32.4s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  34.3s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  35.3s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  37.1s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=uniform; total time=  37.5s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  37.1s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  32.3s
# [CV] END algorithm=auto, leaf_size=40, metric=manhattan, n_neighbors=11, p=1, weights=distance; total time=  34.6s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=  30.1s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=  29.8s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=  36.9s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=  34.9s
# [CV] END algorithm=ball_tree, leaf_size=20, metric=minkowski, n_neighbors=7, p=2, weights=uniform; total time=  38.6s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=15, p=2, weights=uniform; total time=  35.9s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=  42.3s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=  46.6s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=15, p=2, weights=uniform; total time=  33.6s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=  49.1s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=  49.0s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=15, p=2, weights=uniform; total time=  36.9s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=15, p=2, weights=uniform; total time=  37.7s
# [CV] END algorithm=ball_tree, leaf_size=50, metric=minkowski, n_neighbors=7, p=1, weights=uniform; total time=  50.3s
# [CV] END algorithm=kd_tree, leaf_size=20, metric=euclidean, n_neighbors=15, p=2, weights=uniform; total time=  35.1s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=  37.3s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=  39.0s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=  36.3s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=  36.0s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=5, p=1, weights=uniform; total time=  32.9s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=distance; total time=  34.8s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=distance; total time=  34.2s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=distance; total time=  34.5s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=distance; total time=  32.2s
# [CV] END algorithm=kd_tree, leaf_size=30, metric=minkowski, n_neighbors=15, p=1, weights=distance; total time=  31.9s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=KNeighborsClassifier(), n_iter=100, n_jobs=-1,
#                    param_distributions={'algorithm': ['auto', 'ball_tree',
#                                                       'kd_tree', 'brute'],
#                                         'leaf_size': [10, 20, 30, 40, 50],
#                                         'metric': ['euclidean', 'manhattan',
#                                                    'minkowski'],
#                                         'n_neighbors': [3, 5, 7, 9, 11, 13, 15],
#                                         'p': [1, 2],
#                                         'weights': ['uniform', 'distance']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save the best model
with open('best_model.json', 'w') as f:
    json.dump(random_search.best_params_, f)

# %%
# Get the best parameters
best_params = random_search.best_params_
print("Best parameters:", best_params)

# # Load the best parameters from a json file
# with open('knn_optimized_best_params.json', 'r') as f:
#     best_params = json.load(f)

# Now, let's perform a final 5-fold cross-validation using the best model
best_knn = KNeighborsClassifier(**best_params)

fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    best_knn.fit(X_train, y_train)
    y_pred = best_knn.predict(X_val)
    y_prob = best_knn.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob)
    
    # Check for NaN values in y_prob before calculating AUC
    if np.isnan(y_prob).any():
        print(f"NaN values found in y_prob for fold {fold}, skipping AUC calculation")
        double_dichotomy_auc = {'auc_few_vs_many': np.nan}
    else:
        double_dichotomy_auc = calculate_double_dichotomy_auc(y_val, y_prob)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["precision"] * metrics["sensitivity"] / (metrics["precision"] + metrics["sensitivity"]) for i, metrics in enumerate(class_metrics)},
        **double_dichotomy_auc
    }
    
    custom_log(metrics, model_name=f'knn_optimized_{fold}', log_dir='logs')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name='knn_optimized', fold_num=fold)
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items():
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name='knn_optimized_average', log_dir='logs')
# Out:
# Best parameters: {'weights': 'uniform', 'p': 2, 'n_neighbors': 11, 'metric': 'euclidean', 'leaf_size': 10, 'algorithm': 'ball_tree'}
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9879656160458453, 'val_auc': 0.9986820079998584, 'val_f1': 0.9879498714537954, 'avg_sensitivity': 0.9886456802814451, 'avg_specificity': 0.9897166558294893, 'class_Few_sensitivity': 0.9927826784282278, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9731543624161074, 'class_Few_specificity': 0.9759036144578314, 'class_Many_specificity': 0.999409681227863, 'class_None_specificity': 0.9938366718027735, 'class_Few_f1': 0.9842707878347672, 'class_Many_f1': 0.9997047534691467, 'class_None_f1': 0.9833867830292835, 'auc_normal_vs_abnormal': 0.9986754704363621, 'auc_few_vs_many': 1.0}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9845272206303725, 'val_auc': 0.9951999031088391, 'val_f1': 0.984547645560286, 'avg_sensitivity': 0.9875202349920196, 'avg_specificity': 0.9885883624814694, 'class_Few_sensitivity': 0.9871692060946271, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9753914988814317, 'class_Few_specificity': 0.9779116465863453, 'class_Many_specificity': 0.999409681227863, 'class_None_specificity': 0.9884437596302003, 'class_Few_f1': 0.9825186200092271, 'class_Many_f1': 0.9997047534691467, 'class_None_f1': 0.9818742545608369, 'auc_normal_vs_abnormal': 0.9952404835523934, 'auc_few_vs_many': 0.9995911756843876}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9851002865329513, 'val_auc': 0.9984049619512705, 'val_f1': 0.9851104688328318, 'avg_sensitivity': 0.9873061357866426, 'avg_specificity': 0.9889197228649026, 'class_Few_sensitivity': 0.9887640449438202, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9731543624161074, 'class_Few_specificity': 0.9779559118236473, 'class_Many_specificity': 0.9988186650915535, 'class_None_specificity': 0.9899845916795069, 'class_Few_f1': 0.9833302802711119, 'class_Many_f1': 0.9994089834515367, 'class_None_f1': 0.981497333245539, 'auc_normal_vs_abnormal': 0.9974793435435001, 'auc_few_vs_many': 0.9999922829979009}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.929512893982808, 'val_auc': 0.9431200585165577, 'val_f1': 0.9279847694534366, 'avg_sensitivity': 0.8474831880317669, 'avg_specificity': 0.9313986492646048, 'class_Few_sensitivity': 0.9759229534510433, 'class_Many_sensitivity': 0.7450980392156863, 'class_None_sensitivity': 0.8214285714285714, 'class_Few_specificity': 0.8196392785571143, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9745566692367, 'class_Few_f1': 0.8909797402001796, 'class_Many_f1': 0.8539325842696629, 'class_None_f1': 0.8914646673719393, 'auc_normal_vs_abnormal': 0.9459578766934684, 'auc_few_vs_many': 0.9019607843137255}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9827981651376146, 'val_auc': 0.9955943347140268, 'val_f1': 0.9827223643069798, 'avg_sensitivity': 0.9819323400878336, 'avg_specificity': 0.9836307450310106, 'class_Few_sensitivity': 0.992776886035313, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9530201342281879, 'class_Few_specificity': 0.9578313253012049, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9930609097918273, 'class_Few_f1': 0.9749910770939085, 'class_Many_f1': 1.0, 'class_None_f1': 0.9726286009051122, 'auc_normal_vs_abnormal': 0.9953998126807864, 'auc_few_vs_many': 1.0}
# Average results across all folds:
# val_accuracy: 0.9739808364659185
# val_auc: 0.9862002532581104
# val_f1: 0.9736630239214659
# avg_sensitivity: 0.9585775158359416
# avg_specificity: 0.9764508270942954
# class_Few_sensitivity: 0.9874831537906061
# class_Many_sensitivity: 0.9490196078431372
# class_None_sensitivity: 0.9392297858740812
# class_Few_specificity: 0.9418483553452287
# class_Many_specificity: 0.9995276055094559
# class_None_specificity: 0.9879765204282016
# class_Few_f1: 0.9632181010818389
# class_Many_f1: 0.9705502149318985
# class_None_f1: 0.9621703278225422
# auc_normal_vs_abnormal: 0.986550597381302
# auc_few_vs_many: 0.9803088485992028
