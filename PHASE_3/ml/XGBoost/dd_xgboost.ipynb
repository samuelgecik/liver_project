# %%
import os
import sys
import json
import xgboost as xgb
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score, roc_auc_score, f1_score
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.metrics import make_scorer
import numpy as np

# %%
# Add the directory two levels up to sys.path
grandparent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir, os.pardir))
sys.path.insert(0, grandparent_dir)

# Now you can import the module from the grandparent directory
try:
    from metrics import *
    print("Module 'metrics' imported successfully.")
except ModuleNotFoundError as e:
    print(f"Error: {e}")
    print("Ensure that 'metrics.py' is located in the grandparent directory.")
# Out:
# Module 'metrics' imported successfully.

# %%
MODEL_NAME = 'xgb'

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
# Divide the data into 2 classes only (Normal and Abnormal)
y_binary = np.zeros(y.shape)
y_binary[y != 2] = 0 # Few and Many
y_binary[y == 2] = 1 # None

# Check the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y_binary, return_counts=True))

# Define the new class names
binary_class_names = ["Abormal", "Normal"]
print('Binary class names:')
print(binary_class_names)
# Out:
# Number of samples in each class:
# (array([0., 1.]), array([6488, 2236]))
# Binary class names:
# ['Abormal', 'Normal']

# %%
# Define the parameter grid for XGBoost
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': [0.01, 0.1, 0.3],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0],
    'gamma': [0, 0.1, 0.2],
    'min_child_weight': [1, 3, 5]
}

custom_score = custom_score = make_scorer(custom_scorer, greater_is_better=True, 
                           response_method='predict_proba'
                           )

# %%
import cupy as cp

# Convert your data to GPU
X_gpu = cp.array(X)
y_binary_gpu = cp.array(y_binary)

X_gpu_np = cp.asnumpy(X_gpu)
y_binary_gpu_np = cp.asnumpy(y_binary_gpu)

# %%
# Initialize the KNN classifier
xgb_clf = xgb.XGBClassifier(objective='multi:softprob',
                                device='cuda:0',
                                num_class=2,
                                random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=xgb_clf, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=3, 
    random_state=42, 
    # n_jobs=4,
    scoring=custom_score
)

# %%
# random_search.fit(X_gpu_np, y_binary_gpu_np)

# %%
# # Save best parameters
# with open('dd_normal_vs_abnormal_best_params.json', 'w') as f:
#     json.dump(random_search.best_params_, f, indent=4)

# %%
# Get the best parameters
# best_params = random_search.best_params_
# print("Best parameters:", best_params)

# Load the best parameters from a json file
with open('dd_normal_vs_abnormal_best_params.json', 'r') as f:
    best_params = json.load(f)

# Perform 10-fold cross-validation using the best model
best_clsfr_nor_abn = xgb.XGBClassifier(objective='multi:softprob', num_class=2, random_state=42, **best_params)

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y_binary), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y_binary[train_index], y_binary[val_index]
    
    best_clsfr_nor_abn.fit(X_train, y_train)
    y_pred = best_clsfr_nor_abn.predict(X_val)
    y_pred = y_pred.argmax(axis=1)
    y_prob = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{binary_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_f1': 2 * metrics["precision"] * metrics["sensitivity"] / (metrics["precision"] + metrics["sensitivity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_nor_abn', log_dir='logs_dd/nor_vs_abn/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=binary_class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_nor_abn', fold_num=fold, save_dir='figures_dd/nor_vs_abn/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name=f'dd_{MODEL_NAME}_average_nor_abn', log_dir='logs_dd/nor_vs_abn/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9765042979942693, 'val_auc': 0.9938297776996446, 'val_f1': 0.9530355097365406, 'avg_sensitivity': 0.9614723046642055, 'avg_specificity': 0.9614723046642055, 'class_Abormal_sensitivity': 0.9922958397534669, 'class_Normal_sensitivity': 0.930648769574944, 'class_Abormal_specificity': 0.930648769574944, 'class_Normal_specificity': 0.9922958397534669, 'class_Abormal_f1': 0.9604841427475387, 'class_Normal_f1': 0.9604841427475387}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9724928366762178, 'val_auc': 0.9946363877657246, 'val_f1': 0.9463087248322147, 'avg_sensitivity': 0.9639093701202677, 'avg_specificity': 0.9639093701202677, 'class_Abormal_sensitivity': 0.9815100154083205, 'class_Normal_sensitivity': 0.9463087248322147, 'class_Abormal_specificity': 0.9463087248322147, 'class_Normal_specificity': 0.9815100154083205, 'class_Abormal_f1': 0.9635879885421248, 'class_Normal_f1': 0.9635879885421248}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.977650429799427, 'val_auc': 0.996228925588498, 'val_f1': 0.9561304836895388, 'avg_sensitivity': 0.9688429626718786, 'avg_specificity': 0.9688429626718786, 'class_Abormal_sensitivity': 0.9869029275808937, 'class_Normal_sensitivity': 0.9507829977628636, 'class_Abormal_specificity': 0.9507829977628636, 'class_Normal_specificity': 0.9869029275808937, 'class_Abormal_f1': 0.9685063112793605, 'class_Normal_f1': 0.9685063112793605}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9736389684813753, 'val_auc': 0.9910662655578809, 'val_f1': 0.9476082004555809, 'avg_sensitivity': 0.9588886441238023, 'avg_specificity': 0.9588886441238023, 'class_Abormal_sensitivity': 0.9892058596761758, 'class_Normal_sensitivity': 0.9285714285714286, 'class_Abormal_specificity': 0.9285714285714286, 'class_Normal_specificity': 0.9892058596761758, 'class_Abormal_f1': 0.9579301036671165, 'class_Normal_f1': 0.9579301036671165}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9793577981651376, 'val_auc': 0.9932489189473557, 'val_f1': 0.9595505617977528, 'avg_sensitivity': 0.9714605551617137, 'avg_specificity': 0.9714605551617137, 'class_Abormal_sensitivity': 0.9876638396299152, 'class_Normal_sensitivity': 0.9552572706935123, 'class_Abormal_specificity': 0.9552572706935123, 'class_Normal_specificity': 0.9876638396299152, 'class_Abormal_f1': 0.9711902956785443, 'class_Normal_f1': 0.9711902956785443}
# Average results across all folds:
# val_accuracy: 0.9759288662232853
# val_auc: 0.9938020551118207
# val_f1: 0.9525266961023254
# avg_sensitivity: 0.9649147673483736
# avg_specificity: 0.9649147673483736
# class_Abormal_sensitivity: 0.9875156964097543
# class_Normal_sensitivity: 0.9423138382869928
# class_Abormal_specificity: 0.9423138382869928
# class_Normal_specificity: 0.9875156964097543
# class_Abormal_f1: 0.964339768382937
# class_Normal_f1: 0.964339768382937

# %%
# Predict the class Abnormal for each sample using the best model from the first stage
y_pred = best_clsfr_nor_abn.predict(X)
abnormal_indices = np.where(y_pred == 0)[0]
print(f"Number of predicted abnormal samples: {len(abnormal_indices)}")
# Out:
# Number of predicted abnormal samples: 8724

# %%
# Filter the dataset to include only the predicted Abnormal sample
X_pred_abnormal = X[abnormal_indices]
y_pred_abnormal = y[abnormal_indices]

# Check the number of samples in each class
print('Number of samples in each class:')
len(y_pred_abnormal), len(X_pred_abnormal)
# Out:
# Number of samples in each class:
# (8724, 8724)

# %%
print(np.unique(y_pred_abnormal, return_counts=True))
normal_in_abnormal = y_pred_abnormal == 2  # 2 is the label for Normal
len(y_pred_abnormal[normal_in_abnormal])
# Out:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# 2236

# %%
X_abnormal = X_pred_abnormal[~normal_in_abnormal]
y_abnormal = y_pred_abnormal[~normal_in_abnormal]

# Check the number of samples in each class
print('Number of samples in each class:')
np.unique(y_abnormal, return_counts=True)
# Out:
# Number of samples in each class:
# (array([0, 1]), array([6232,  256]))

# %%
# Initialize RandomizedSearchCV
random_search_abn = RandomizedSearchCV(
    estimator=xgb_clf, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=3 , 
    random_state=42, 
    # n_jobs=-1,
    scoring=custom_score
)

# %%
random_search_abn.fit(X_abnormal, y_abnormal)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /home/samo/dev/liver/.venv/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [16:11:50] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=   4.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.990 total time=   3.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.863 total time=   3.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.7s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=   4.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.861 total time=   3.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=   5.0s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.9s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.868 total time=   1.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.988 total time=   1.8s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   1.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.990 total time=   1.8s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.871 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.8s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.872 total time=   1.0s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.868 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.988 total time=   2.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   8.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   8.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   8.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.872 total time=   5.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   8.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.8;, score=1.000 total time=   3.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.870 total time=   3.0s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8;, score=1.000 total time=   3.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.871 total time=   2.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=   4.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.873 total time=   4.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=   4.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.863 total time=   3.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.990 total time=   3.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   3.7s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   3.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.854 total time=   2.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.990 total time=   3.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=   4.7s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.873 total time=   4.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=   4.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.857 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.8;, score=1.000 total time=   4.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.871 total time=   3.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.988 total time=   4.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=1.000 total time=   3.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.871 total time=   2.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.9s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   9.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   9.8s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   9.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.865 total time=   5.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   9.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=1.000 total time=   3.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.868 total time=   3.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.865 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=1.0;, score=0.990 total time=   2.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.867 total time=   1.6s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=3, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.867 total time=   3.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=1.0;, score=1.000 total time=   4.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.874 total time=   3.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.988 total time=   4.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.865 total time=   0.9s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.862 total time=   3.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   4.4s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   9.0s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   8.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.990 total time=   8.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.867 total time=   5.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   8.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=1.000 total time=   1.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.857 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.990 total time=   2.0s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   2.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.990 total time=   2.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.864 total time=   1.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   2.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8;, score=1.000 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.862 total time=   2.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.988 total time=   2.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.869 total time=   2.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.9s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.9s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.860 total time=   1.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=1.000 total time=   1.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.870 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.867 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.7s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.7s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.870 total time=   1.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.869 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.861 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.995 total time=   4.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.995 total time=   4.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.990 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.865 total time=   2.5s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.990 total time=   4.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8;, score=1.000 total time=   2.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.871 total time=   1.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.988 total time=   2.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   4.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.871 total time=   3.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.9s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.990 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.857 total time=   2.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.990 total time=   2.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.8;, score=1.000 total time=   3.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.874 total time=   3.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.869 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=  11.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=  11.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=  11.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.865 total time=   5.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=  11.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   2.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.990 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.868 total time=   1.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.1, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   2.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=1.000 total time=   2.1s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   2.1s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   2.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.868 total time=   1.8s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   2.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=1.000 total time=   3.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.990 total time=   3.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.866 total time=   3.2s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=1.000 total time=   3.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.3s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.3s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.862 total time=   2.0s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=1.000 total time=   1.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.8s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.8s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.865 total time=   1.5s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=200, subsample=0.8;, score=0.988 total time=   1.8s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.990 total time=   1.4s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.866 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.3s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=1.000 total time=   3.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.990 total time=   3.8s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.871 total time=   3.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.988 total time=   3.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=1.000 total time=   3.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.868 total time=   2.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.7s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.862 total time=   3.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.8;, score=1.000 total time=   2.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   2.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.866 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.988 total time=   2.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=  10.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=  10.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=  10.7s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.862 total time=   5.6s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=  10.7s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.4s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.870 total time=   2.9s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.874 total time=   1.3s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   2.2s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=1.000 total time=  10.7s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.995 total time=  10.4s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.995 total time=  10.6s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.870 total time=   5.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=500, subsample=1.0;, score=0.988 total time=  10.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=1.000 total time=   2.2s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.2s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.990 total time=   2.2s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.864 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.988 total time=   2.2s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.3s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.4s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.1s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.868 total time=   0.9s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.988 total time=   1.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=100, subsample=0.8;, score=0.995 total time=   2.3s
# ...
# [CV 3/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.8s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.868 total time=   3.0s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.1, learning_rate=0.1, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.8s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=1.000 total time=   3.5s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.865 total time=   3.0s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.5s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=1.000 total time=   3.4s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.3s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.873 total time=   2.2s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=1.000 total time=   1.9s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.5s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.856 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.988 total time=   1.5s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.868 total time=   1.4s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=1.000 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.995 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.874 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=100, subsample=0.8;, score=0.988 total time=   1.1s
# [CV 1/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0;, score=1.000 total time=   2.2s
# [CV 2/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.1s
# [CV 3/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.2s
# [CV 4/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.862 total time=   1.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0;, score=0.988 total time=   2.0s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=1.000 total time=   2.6s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.9s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.995 total time=   2.5s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.863 total time=   2.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.9s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=1.000 total time=   2.0s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.0s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   2.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.868 total time=   1.1s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.990 total time=   2.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=1.000 total time=   3.8s
# [CV 2/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   3.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.995 total time=   4.0s
# [CV 4/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.865 total time=   3.7s
# [CV 5/5] END colsample_bytree=1.0, gamma=0.2, learning_rate=0.1, max_depth=3, min_child_weight=1, n_estimators=500, subsample=0.8;, score=0.988 total time=   3.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.995 total time=   1.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.861 total time=   1.4s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.2, learning_rate=0.3, max_depth=3, min_child_weight=5, n_estimators=200, subsample=1.0;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=1.000 total time=   1.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.3s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.867 total time=   0.9s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, subsample=1.0;, score=0.988 total time=   1.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   7.5s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   7.0s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   7.0s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.874 total time=   4.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=9, min_child_weight=5, n_estimators=500, subsample=0.8;, score=0.995 total time=   7.3s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   6.3s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   6.6s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.995 total time=   6.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.865 total time=   4.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=3, min_child_weight=5, n_estimators=500, subsample=1.0;, score=0.988 total time=   6.1s
# [CV 1/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=1.000 total time=   1.7s
# [CV 2/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 3/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.995 total time=   1.6s
# [CV 4/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.868 total time=   1.3s
# [CV 5/5] END colsample_bytree=1.0, gamma=0, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, subsample=0.8;, score=0.988 total time=   1.6s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=1.000 total time=   1.8s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.9s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.8s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.857 total time=   1.1s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=5, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.990 total time=   2.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.1s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.2s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.995 total time=   1.1s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.874 total time=   0.8s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.3, max_depth=9, min_child_weight=5, n_estimators=100, subsample=1.0;, score=0.988 total time=   1.0s
# [CV 1/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8;, score=1.000 total time=   4.6s
# [CV 2/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   4.5s
# [CV 3/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.995 total time=   4.5s
# [CV 4/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.862 total time=   2.7s
# [CV 5/5] END colsample_bytree=0.8, gamma=0.1, learning_rate=0.01, max_depth=7, min_child_weight=1, n_estimators=200, subsample=0.8;, score=0.988 total time=   4.9s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None,
#                                            device='cuda:0',
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impo...
#                                            n_estimators=None, n_jobs=None,
#                                            num_class=2, num_parallel_tree=None, ...),
#                    n_iter=100,
#                    param_distributions={'colsample_bytree': [0.8, 1.0],
#                                         'gamma': [0, 0.1, 0.2],
#                                         'learning_rate': [0.01, 0.1, 0.3],
#                                         'max_depth': [3, 5, 7, 9],
#                                         'min_child_weight': [1, 3, 5],
#                                         'n_estimators': [100, 200, 500],
#                                         'subsample': [0.8, 1.0]},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=3)

# %%
# Save best parameters few vs many
with open('dd_few_vs_many_best_params.json', 'w') as f:
    json.dump(random_search_abn.best_params_, f, indent=4)

# %%
# Load the best parameters from a json file
with open('dd_few_vs_many_best_params.json', 'r') as f:
    best_params_abn = json.load(f)

best_clsfr_few_many = xgb.XGBClassifier(objective='multi:softprob', num_class=2, random_state=42, **best_params_abn)


abn_class_names = ["Few", "Many"]

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X_abnormal, y_abnormal), 1):
    print(f"Fold {fold}")
    X_train, X_val = X_abnormal[train_index], X_abnormal[val_index]
    y_train, y_val = y_abnormal[train_index], y_abnormal[val_index]
    
    best_clsfr_few_many.fit(X_train, y_train)
    y_pred = best_clsfr_few_many.predict(X_val)
    y_pred = y_pred.argmax(axis=1)
    y_prob = best_clsfr_few_many.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{abn_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_f1': 2 * metrics["precision"] * metrics["sensitivity"] / (metrics["precision"] + metrics["sensitivity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_few_many', log_dir='logs_dd/few_vs_many/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=abn_class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_few_many', fold_num=fold, save_dir='figures_dd/few_vs_many/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name=f'dd_{MODEL_NAME}_few_many_average', log_dir='logs_dd/few_vs_many/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 1.0, 'val_auc': 1.0, 'val_f1': 1.0, 'avg_sensitivity': 1.0, 'avg_specificity': 1.0, 'class_Few_sensitivity': 1.0, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 1.0, 'class_Few_f1': 1.0, 'class_Many_f1': 1.0}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9992295839753467, 'val_auc': 0.999984275987861, 'val_f1': 0.9902912621359223, 'avg_sensitivity': 0.9995990376904571, 'avg_specificity': 0.9995990376904571, 'class_Few_sensitivity': 0.9991980753809142, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 0.9991980753809142, 'class_Few_f1': 0.9995988768551946, 'class_Many_f1': 0.9995988768551946}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9992295839753467, 'val_auc': 1.0, 'val_f1': 0.9904761904761905, 'avg_sensitivity': 0.9995987158908507, 'avg_specificity': 0.9995987158908507, 'class_Few_sensitivity': 0.9991974317817014, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 0.9991974317817014, 'class_Few_f1': 0.9995985547972701, 'class_Many_f1': 0.9995985547972701}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9884348496530455, 'val_auc': 0.9572435715859376, 'val_f1': 0.8275862068965517, 'avg_sensitivity': 0.8529411764705883, 'avg_specificity': 0.8529411764705883, 'class_Few_sensitivity': 1.0, 'class_Many_sensitivity': 0.7058823529411765, 'class_Few_specificity': 0.7058823529411765, 'class_Many_specificity': 1.0, 'class_Few_f1': 0.8275862068965517, 'class_Many_f1': 0.8275862068965517}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9992289899768697, 'val_auc': 1.0, 'val_f1': 0.9902912621359223, 'avg_sensitivity': 0.9995987158908507, 'avg_specificity': 0.9995987158908507, 'class_Few_sensitivity': 0.9991974317817014, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 0.9991974317817014, 'class_Few_f1': 0.9995985547972701, 'class_Many_f1': 0.9995985547972701}
# Average results across all folds:
# val_accuracy: 0.9972246015161217
# val_auc: 0.9914455695147598
# val_f1: 0.9597289843289174
# avg_sensitivity: 0.9703475291885493
# avg_specificity: 0.9703475291885493
# class_Few_sensitivity: 0.9995185877888634
# class_Many_sensitivity: 0.9411764705882353
# class_Few_specificity: 0.9411764705882353
# class_Many_specificity: 0.9995185877888634
# class_Few_f1: 0.9652764386692573
# class_Many_f1: 0.9652764386692573

# %%
def combine_predictions(normal_abnormal_pred, few_many_pred):
    # Initialize final_pred with the same shape as normal_abnormal_pred, filled with 2 (Normal)
    final_pred = np.full(normal_abnormal_pred.shape, 2)
    
    # Create a mask where normal_abnormal_pred is 0 (Abnormal)
    abnormal_mask = normal_abnormal_pred == 0
    
    # Update final_pred where the mask is True with values from few_many_pred
    final_pred[abnormal_mask] = few_many_pred
    
    # Return the final combined predictions
    return final_pred

def combine_probabilities(normal_abnormal_prob, few_many_prob, abnormal_mask):
    # Initialize with probabilities for Normal class
    combined_prob = np.column_stack((np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     normal_abnormal_prob[:, 1]))
    
    # Update probabilities for Abnormal (Few and Many) classes
    if few_many_prob.size > 0:
        combined_prob[abnormal_mask, 0] = few_many_prob[:, 0] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 1] = few_many_prob[:, 1] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 2] = 0  # Probability of being Normal for predicted Abnormal samples
    
    # Normalize probabilities
    row_sums = combined_prob.sum(axis=1)
    combined_prob /= row_sums[:, np.newaxis]
    
    return combined_prob

# %%
overall_true = []
overall_pred = []
overall_prob = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Stage 1: Normal vs Abnormal
    y_train_binary = (y_train == 2).astype(int)
    best_clsfr_nor_abn.fit(X_train, y_train_binary)
    y_pred_binary = best_clsfr_nor_abn.predict(X_val)
    y_pred_binary = y_pred_binary.argmax(axis=1)
    y_prob_binary = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Stage 2: Few vs Many (only for predicted Abnormal samples)
    abnormal_mask_train = y_train != 2
    X_train_abnormal = X_train[abnormal_mask_train]
    y_train_abnormal = y_train[abnormal_mask_train]
    
    best_clsfr_few_many.fit(X_train_abnormal, y_train_abnormal)
    
    abnormal_mask_val = y_pred_binary == 0
    X_val_abnormal = X_val[abnormal_mask_val]
    
    if len(X_val_abnormal) > 0:
        y_pred_few_many = best_clsfr_few_many.predict(X_val_abnormal)
        y_pred_few_many = y_pred_few_many.argmax(axis=1)
        y_prob_few_many = best_clsfr_few_many.predict_proba(X_val_abnormal)
    else:
        y_pred_few_many = np.array([])
        y_prob_few_many = np.array([])
    
    # Combine predictions and probabilities
    y_pred_combined = combine_predictions(y_pred_binary, y_pred_few_many)
    y_prob_combined = combine_probabilities(y_prob_binary, y_prob_few_many, abnormal_mask_val)
    
    overall_true.extend(y_val)
    overall_pred.extend(y_pred_combined)
    overall_prob.extend(y_prob_combined)
    
    # Calculate and log metrics for this fold
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred_combined, y_prob_combined, num_classes=3)
     
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["precision"] * metrics["sensitivity"] / (metrics["precision"] + metrics["sensitivity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_combined', log_dir='logs_dd/combined/')
    print("Metrics for this fold:")
    print(metrics)
    
    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_combined', fold_num=fold, save_dir='figures_dd/combined/')

# Calculate overall metrics
overall_true = np.array(overall_true)
overall_pred = np.array(overall_pred)
overall_prob = np.array(overall_prob)

accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(overall_true, overall_pred, overall_prob, num_classes=3)

overall_metrics = {
    'overall_accuracy': accuracy,
    'overall_auc': auc,
    'overall_f1': f1,
    'overall_avg_sensitivity': avg_sensitivity,
    'overall_avg_specificity': avg_specificity,
    **{f'overall_class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_f1': 2 * metrics["precision"] * metrics["sensitivity"] / (metrics["precision"] + metrics["sensitivity"]) for i, metrics in enumerate(class_metrics)},
}

print("Overall metrics:")
for key, value in overall_metrics.items():
    print(f"{key}: {value}")

custom_log(overall_metrics, model_name=f'dd_{MODEL_NAME}_combined_overall', log_dir='logs_dd/combined/')

# Plot overall confusion matrix
plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_combined_overall', save_dir='figures_dd/combined/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9879656160458453, 'val_auc': 0.9867475677519018, 'val_f1': 0.9879612895691304, 'avg_sensitivity': 0.9891240842301913, 'avg_specificity': 0.9900691621132708, 'class_Few_sensitivity': 0.991980753809142, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9753914988814317, 'class_Few_specificity': 0.9779116465863453, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9922958397534669, 'class_Few_f1': 0.9848959589312646, 'class_Many_f1': 1.0, 'class_None_f1': 0.9837710569834908}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9862464183381089, 'val_auc': 0.9887170009884302, 'val_f1': 0.9862601941541317, 'avg_sensitivity': 0.9888005635598516, 'avg_specificity': 0.9897713172074099, 'class_Few_sensitivity': 0.9887730553327987, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9776286353467561, 'class_Few_specificity': 0.9799196787148594, 'class_Many_specificity': 0.999409681227863, 'class_None_specificity': 0.9899845916795069, 'class_Few_f1': 0.9843264598346106, 'class_Many_f1': 0.9997047534691467, 'class_None_f1': 0.9837678178659993}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9839541547277937, 'val_auc': 0.9868029408515265, 'val_f1': 0.9839642866065287, 'avg_sensitivity': 0.9862929008921015, 'avg_specificity': 0.9879949148513406, 'class_Few_sensitivity': 0.9879614767255217, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.970917225950783, 'class_Few_specificity': 0.9759519038076152, 'class_Many_specificity': 0.9988186650915535, 'class_None_specificity': 0.9892141756548536, 'class_Few_f1': 0.9819199702556198, 'class_Many_f1': 0.9994089834515367, 'class_None_f1': 0.9799803038829488}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.932378223495702, 'val_auc': 0.9063560875752, 'val_f1': 0.9307289258679992, 'avg_sensitivity': 0.8377135264218047, 'avg_specificity': 0.932683665969822, 'class_Few_sensitivity': 0.9791332263242376, 'class_Many_sensitivity': 0.7058823529411765, 'class_None_sensitivity': 0.828125, 'class_Few_specificity': 0.8196392785571143, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9784117193523516, 'class_Few_f1': 0.8923152305895776, 'class_Many_f1': 0.8275862068965517, 'class_None_f1': 0.8970171449148756}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9850917431192661, 'val_auc': 0.9840332182428795, 'val_f1': 0.9850558671007884, 'avg_sensitivity': 0.9853933781239413, 'avg_specificity': 0.986780576093793, 'class_Few_sensitivity': 0.9919743178170144, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9642058165548099, 'class_Few_specificity': 0.9678714859437751, 'class_Many_specificity': 0.9994093325457767, 'class_None_specificity': 0.9930609097918273, 'class_Few_f1': 0.979774689581449, 'class_Many_f1': 0.9997045790251108, 'class_None_f1': 0.9784206644147616}
# Overall metrics:
# overall_accuracy: 0.975126088950023
# overall_auc: 0.9637361567377378
# overall_f1: 0.9750266700530057
# overall_avg_sensitivity: 0.9575245789567455
# overall_avg_specificity: 0.9774478234206461
# overall_class_Few_sensitivity: 0.9879653401797176
# overall_class_Many_sensitivity: 0.94140625
# overall_class_None_sensitivity: 0.9432021466905188
# overall_class_Few_specificity: 0.9442215088282504
# overall_class_Many_specificity: 0.9995276334435522
# overall_class_None_specificity: 0.9885943279901356
# overall_class_Few_f1: 0.9655982542821475
# overall_class_Many_f1: 0.9695967175368597
# overall_class_None_f1: 0.9653649383747935
