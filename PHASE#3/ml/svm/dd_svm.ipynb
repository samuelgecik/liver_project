# %%
import os
import json
from metrics import *
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC

# %%
model_name = 'svm'

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
# Divide the data into 2 classes only (Normal and Abnormal)
y_binary = np.zeros(y.shape)
y_binary[y != 2] = 0 # Few and Many
y_binary[y == 2] = 1 # None

# Check the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y_binary, return_counts=True))

# Define the new class names
binary_class_names = ["Abormal", "Normal"]
print('Binary class names:')
print(binary_class_names)
# Out:
# Number of samples in each class:
# (array([0., 1.]), array([6488, 2236]))
# Binary class names:
# ['Abormal', 'Normal']

# %%
# Define the parameter grid for SVM
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'class_weight': ['balanced', None]
}

custom_score = custom_score = make_scorer(custom_scorer, greater_is_better=True, 
                           response_method='predict_proba'
                           )

# %%
# Initialize the KNN classifier
svm = SVC(probability=True, random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=svm, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.0min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.8min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 2.1min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.0min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.8min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.9min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.9min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 4.0min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 1.2min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.0min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.2min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.2min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.0min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.9min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.5min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 1.6min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.5min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.1min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.6min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.0min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.4min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.6min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 4.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 4.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 4.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 3.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=11.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=13.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=16.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=17.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=17.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.5min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.7min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=13.1min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.6min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.8min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.5min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 6.1min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 6.4min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.4min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 6.1min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.8min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.6min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.7min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 5.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 1.7min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.1min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 1.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=30.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=32.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.4min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.0min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.0min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=11.6min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.3min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.9min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.2min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.4min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 4.0min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.3min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.4min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 1.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 4.0min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.9min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.8min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.7min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.0min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.0min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.1min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.3min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 1.4min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.1min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.4min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.5min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.1min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.7min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 1.2min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.4min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.4min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.0min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.8min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.2min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 8.6min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.9min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.5min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.5min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 1.8min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.4min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.8min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.5min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.4min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=10.0min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=12.4min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=12.6min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=12.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=29.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=29.3min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=29.7min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.1min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.4min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.5min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=11.6min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.1min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.4min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 1.4min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.6min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.6min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.6min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.5min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.4min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.2min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.9min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.5min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.6min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.0min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.6min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.5min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.9min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 1.2min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 9.9min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 9.6min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 9.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time=10.2min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 1.6min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time=10.7min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.1min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 1.1min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.7min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.9min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.6min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.6min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 1.8min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.4min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.8min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.5min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.7min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 1.5min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 4.0min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.4min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=10.4min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.7min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.6min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=10.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.4min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.0min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.6min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.0min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.5min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.6min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.1min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.9min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=33.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.4min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.9min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.3min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.9min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=12.3min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=12.0min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=12.6min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.6min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.3min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.7min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.5min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.6min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.7min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.4min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.8min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.5min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.8min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.0min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.5min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.4min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.0min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.8min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.4min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.9min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=12.2min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=12.1min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.9min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.9min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.6min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=14.8min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.1min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=21.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.7min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.4min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=21.8min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=21.8min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=22.3min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.1min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=22.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 3.2min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.9min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=14.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.1min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.7min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.7min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.5min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.2min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=14.6min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.4min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.7min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.7min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.4min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=12.1min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 4.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 4.1min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.5min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.1min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.8min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.2min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.7min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=13.5min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=13.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.5min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.7min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.7min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.9min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=13.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.2min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.0min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.5min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.0min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.9min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.3min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 1.7min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.1min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.0min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.1min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 1.2min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.5min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.7min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.7min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 2.6min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.6min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.0min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.4min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.1min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.8min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 4.3min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.9min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 4.2min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.2min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.4min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.3min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.4min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=  59.8s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.5min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.1min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.2min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.6min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 1.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.9min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.2min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 6.0min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 1.8min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=  54.4s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.6min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.1min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 3.0min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 1.5min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 1.3min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.2min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.3min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.9min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=  56.6s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 3.1min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.7min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.8min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.0min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.5min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.8min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.5min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.5min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.7min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.6min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 6.3min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.1min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=16.1min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=18.2min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=16.6min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=17.1min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=18.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 5.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.0min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.7min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=31.1min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.0min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 3.3min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 5.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.9min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 4.1min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 1.5min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.7min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.0min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.5min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 1.4min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.2min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.3min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.1min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.1min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=  59.1s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 2.0min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 2.1min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.2min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.9min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=34.9min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=35.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=33.7min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=34.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=36.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 1.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.8min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.8min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.1min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.0min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.6min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=26.0min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=25.9min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.8min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 4.0min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=26.4min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.5min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.1min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=25.6min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.8min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 1.1min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.6min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=35.5min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=35.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=35.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=36.6min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.7min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=36.2min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=27.3min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.3min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.5min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  54.8s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.0min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  54.0s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=SVC(probability=True, random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': ['balanced', None],
#                                         'gamma': ['scale', 'auto', 0.001, 0.01,
#                                                   0.1, 1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save best parameters
with open('dd_normal_vs_abnormal_best_params.json', 'w') as f:
    json.dump(random_search.best_params_, f, indent=4)

# %%
# Get the best parameters
best_params = random_search.best_params_
print("Best parameters:", best_params)

# Load the best parameters from a json file
# with open('dd_normal_vs_abnormal_best_params.json', 'r') as f:
#     best_params = json.load(f)

# Perform 10-fold cross-validation using the best model
best_clsfr_nor_abn = SVC(**best_params, probability=True, random_state=42)
# Out:
# Best parameters: {'kernel': 'rbf', 'gamma': 0.1, 'class_weight': 'balanced', 'C': 1}

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y_binary), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y_binary[train_index], y_binary[val_index]
    
    best_clsfr_nor_abn.fit(X_train, y_train)
    y_pred = best_clsfr_nor_abn.predict(X_val)
    y_prob = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{binary_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_svm', log_dir='logs_dd/nor_vs_abn/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=binary_class_names, epoch_num=0, model_name='dd_svm', fold_num=fold, save_dir='figures_dd/nor_vs_abn/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name='dd_svm', log_dir='logs_dd/nor_vs_abn/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9742120343839542, 'val_auc': 0.9934040668314357, 'val_f1': 0.9494949494949495, 'avg_sensitivity': 0.9650649941572476, 'avg_specificity': 0.9650649941572476, 'class_Abormal_sensitivity': 0.9838212634822804, 'class_Normal_sensitivity': 0.9463087248322147, 'class_Abormal_specificity': 0.9463087248322147, 'class_Normal_specificity': 0.9838212634822804, 'class_Abormal_f1': 0.9647004615701958, 'class_Normal_f1': 0.9647004615701958}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.966189111747851, 'val_auc': 0.9944795469195424, 'val_f1': 0.9362162162162162, 'avg_sensitivity': 0.9670056841880297, 'avg_specificity': 0.9670056841880297, 'class_Abormal_sensitivity': 0.9653312788906009, 'class_Normal_sensitivity': 0.9686800894854586, 'class_Abormal_specificity': 0.9686800894854586, 'class_Normal_specificity': 0.9653312788906009, 'class_Abormal_f1': 0.967002784894731, 'class_Normal_f1': 0.967002784894731}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9742120343839542, 'val_auc': 0.9954602330896267, 'val_f1': 0.9507119386637459, 'avg_sensitivity': 0.9731319565809384, 'avg_specificity': 0.9731319565809384, 'class_Abormal_sensitivity': 0.975346687211094, 'class_Normal_sensitivity': 0.970917225950783, 'class_Abormal_specificity': 0.970917225950783, 'class_Normal_specificity': 0.975346687211094, 'class_Abormal_f1': 0.9731269161219022, 'class_Normal_f1': 0.9731269161219022}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9656160458452722, 'val_auc': 0.9902298573631457, 'val_f1': 0.9343544857768052, 'avg_sensitivity': 0.9615278045489591, 'avg_specificity': 0.9615278045489591, 'class_Abormal_sensitivity': 0.9699306090979183, 'class_Normal_sensitivity': 0.953125, 'class_Abormal_specificity': 0.953125, 'class_Normal_specificity': 0.9699306090979183, 'class_Abormal_f1': 0.9614543723258305, 'class_Normal_f1': 0.9614543723258305}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9696100917431193, 'val_auc': 0.9915878839310817, 'val_f1': 0.9419496166484118, 'avg_sensitivity': 0.9671061596283973, 'avg_specificity': 0.9671061596283973, 'class_Abormal_sensitivity': 0.9722436391673092, 'class_Normal_sensitivity': 0.9619686800894854, 'class_Abormal_specificity': 0.9619686800894854, 'class_Normal_specificity': 0.9722436391673092, 'class_Abormal_f1': 0.9670788682129203, 'class_Normal_f1': 0.9670788682129203}
# Average results across all folds:
# val_accuracy: 0.9699678636208302
# val_auc: 0.9930323176269663
# val_f1: 0.9425454413600258
# avg_sensitivity: 0.9667673198207144
# avg_specificity: 0.9667673198207144
# class_Abormal_sensitivity: 0.9733346955698405
# class_Normal_sensitivity: 0.9601999440715885
# class_Abormal_specificity: 0.9601999440715885
# class_Normal_specificity: 0.9733346955698405
# class_Abormal_f1: 0.9666726806251159
# class_Normal_f1: 0.9666726806251159

# %%
# Predict the class Abnormal for each sample using the best model from the first stage
y_pred = best_clsfr_nor_abn.predict(X)
abnormal_indices = np.where(y_pred == 0)[0]
print(f"Number of predicted abnormal samples: {len(abnormal_indices)}")
# Out:
# Number of predicted abnormal samples: 6393

# %%
# Filter the dataset to include only the predicted Abnormal sample
X_pred_abnormal = X[abnormal_indices]
y_pred_abnormal = y[abnormal_indices]

# Check the number of samples in each class
print('Number of samples in each class:')
len(y_pred_abnormal), len(X_pred_abnormal)
# Out:
# Number of samples in each class:
# (6393, 6393)

# %%
print(np.unique(y_pred_abnormal, return_counts=True))
normal_in_abnormal = y_pred_abnormal == 2  # 2 is the label for Normal
len(y_pred_abnormal[normal_in_abnormal])
# Out:
# (array([0, 1, 2]), array([6060,  252,   81]))
# 81

# %%
X_abnormal = X_pred_abnormal[~normal_in_abnormal]
y_abnormal = y_pred_abnormal[~normal_in_abnormal]

# Check the number of samples in each class
print('Number of samples in each class:')
np.unique(y_abnormal, return_counts=True)
# Out:
# Number of samples in each class:
# (array([0, 1]), array([6060,  252]))

# %%
# Initialize RandomizedSearchCV
random_search_abn = RandomizedSearchCV(
    estimator=svm, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search_abn.fit(X_abnormal, y_abnormal)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   6.8s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   6.9s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.0s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.1s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.2s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   8.0s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   9.3s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   5.5s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   5.8s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   5.8s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  24.9s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  44.6s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  45.4s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  32.6s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  45.7s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  46.1s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  49.4s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  43.4s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.5s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  47.2s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   8.8s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  49.4s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  45.0s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.4s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  21.2s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  49.9s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  26.7s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  28.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  29.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  55.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  55.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  41.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  56.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  29.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  30.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  32.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.2min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  43.7s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  42.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  19.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  26.0s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  43.3s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  47.5s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  46.6s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  18.3s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  26.6s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  27.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  36.3s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  36.6s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  37.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  38.8s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  35.2s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  49.8s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  26.6s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  42.1s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  25.9s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  30.0s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  31.5s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  30.4s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  29.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  40.7s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  32.7s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  13.6s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  18.9s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  41.9s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  45.9s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  16.2s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  47.9s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  19.2s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  42.2s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  48.6s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  22.6s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  27.6s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  45.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  47.8s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  46.4s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  40.6s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  41.1s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  42.4s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  28.4s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  33.6s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  22.9s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  26.7s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  33.5s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  34.0s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  27.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.5min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  27.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.4min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  17.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.6min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  11.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.5min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  40.0s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  41.3s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  16.1s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  11.6s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  47.4s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  42.7s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  15.9s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  15.1s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  23.5s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  22.6s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  30.3s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  25.2s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  30.8s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.5min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.9min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   9.3s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   9.5s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=  10.1s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   8.5s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   8.5s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.9min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=  57.7s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.2min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  24.3s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=  59.5s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  32.0s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  26.4s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  30.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  25.8s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  32.8s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  32.4s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  36.8s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  27.9s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  39.3s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  25.1s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  36.2s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 6.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.0min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  13.7s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  36.3s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  30.2s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  13.5s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  16.5s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  17.0s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  15.5s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  32.5s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   7.2s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   8.7s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.3min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   9.1s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   7.7s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   7.2s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=   9.6s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  11.6s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  10.4s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  11.3s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  12.7s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.6min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   8.2s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=  10.6s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   8.1s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   7.7s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   7.0s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  10.5s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  14.9s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  11.2s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  12.0s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  12.1s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  22.3s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  24.5s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  29.0s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  27.8s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  29.6s
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  41.0s
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  47.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.7min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  46.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  28.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.3min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  43.5s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.6min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  47.3s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  38.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.7min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  27.4s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  29.7s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  31.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  19.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  21.4s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  28.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  27.6s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   7.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  23.6s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   6.6s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   9.0s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   6.1s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   7.9s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  44.3s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  11.3s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  44.8s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  42.6s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  42.4s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  13.7s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  11.7s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  12.1s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  13.0s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  46.9s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  13.2s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  14.0s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  12.5s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  12.4s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  11.4s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  47.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  49.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  56.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  59.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 1.0min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  49.8s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  53.0s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.4min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.6min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.7min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  46.3s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  50.5s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  46.3s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  52.3s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  48.5s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  49.8s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 2.9min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  46.3s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  12.4s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  46.3s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  13.6s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  20.1s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  17.5s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  58.7s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  20.2s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  22.0s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time= 1.0min[CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  56.5s
#
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  21.9s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.1min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time= 1.0min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  28.4s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time= 1.0min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  26.6s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  24.7s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  41.2s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  48.3s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  43.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.6min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  49.6s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  46.3s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  50.6s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.4min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  57.6s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  29.3s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  36.6s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  48.0s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  55.8s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  49.2s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  34.5s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  31.3s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  36.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  28.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  32.3s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  30.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  38.2s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  19.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  29.9s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  18.5s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  20.3s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  19.2s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  23.6s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  22.6s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  24.5s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  35.0s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  39.9s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  27.2s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  33.4s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  11.0s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  31.0s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  26.4s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  14.5s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  11.6s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  12.8s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  28.2s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  27.8s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  14.6s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   7.1s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   8.2s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   8.9s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   6.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  26.2s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  22.5s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   7.3s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  26.3s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  29.5s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  27.5s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  13.0s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  13.4s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.8s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  23.6s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.4s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  41.9s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  16.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  42.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  45.2s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  52.6s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  47.4s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  47.7s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  36.4s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  47.3s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   5.2s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  50.5s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  46.5s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=  10.3s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  43.2s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   7.0s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   6.4s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  56.1s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   7.9s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 6.9min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  38.4s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  36.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  19.2s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  21.9s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  22.6s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  27.3s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 7.0min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   7.7s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  27.2s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   7.5s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   6.3s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  28.3s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   8.2s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   6.5s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   8.0s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   6.9s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   8.2s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   7.7s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  29.2s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   8.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  29.3s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  10.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  29.8s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  27.0s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  11.5s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  15.2s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.8s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  13.0s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  13.5s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   7.0s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   6.0s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   6.9s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.4s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 7.9min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  21.3s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  25.7s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  23.6s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 7.8min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  28.9s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  27.6s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  18.3s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  19.4s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  31.0s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  29.2s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  18.9s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  30.4s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  31.4s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  20.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  32.9s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  21.2s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  13.2s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  22.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  14.6s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  18.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  23.4s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 3.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 6.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 6.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 6.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 7.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 7.3min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  53.1s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  53.2s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  58.7s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  19.8s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  59.6s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 8.8min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 8.8min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  51.9s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  33.1s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  20.3s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  24.6s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.3min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.3min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  26.2s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   7.5s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   9.0s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  29.0s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   7.4s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   7.8s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  31.1s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   7.7s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   6.4s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   8.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  30.2s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   8.0s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   9.3s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  41.1s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   8.7s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   5.3s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   6.6s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   5.5s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   6.3s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   5.8s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  36.5s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   6.4s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   7.5s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   6.3s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   7.0s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   7.8s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   8.9s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   7.5s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=  11.0s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   8.5s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   8.9s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=12.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=12.5min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 3.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  20.7s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  29.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  24.2s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.6min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  27.7s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  30.2s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  25.1s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  21.7s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  21.4s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  21.2s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.2min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  32.3s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  30.4s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.0min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  33.2s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  32.1s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  32.2s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.5min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  44.2s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  11.5s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  11.8s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  15.1s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  15.1s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  14.7s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  17.1s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  15.3s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.5min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  23.5s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  22.6s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  22.7s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  17.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=12.0min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  18.8s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  13.0s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  23.8s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  17.9s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  18.1s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  22.9s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  15.3s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  13.1s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  17.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=10.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=10.0min
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=SVC(probability=True, random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': ['balanced', None],
#                                         'gamma': ['scale', 'auto', 0.001, 0.01,
#                                                   0.1, 1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save best parameters few vs many
with open('dd_few_vs_many_best_params.json', 'w') as f:
    json.dump(random_search_abn.best_params_, f, indent=4)

# %%
# Load the best parameters from a json file
with open('dd_few_vs_many_best_params.json', 'r') as f:
    best_params_abn = json.load(f)

best_clsfr_few_many = SVC(**best_params_abn, probability=True, random_state=42)

abn_class_names = ["Few", "Many"]

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X_abnormal, y_abnormal), 1):
    print(f"Fold {fold}")
    X_train, X_val = X_abnormal[train_index], X_abnormal[val_index]
    y_train, y_val = y_abnormal[train_index], y_abnormal[val_index]
    
    best_clsfr_few_many.fit(X_train, y_train)
    y_pred = best_clsfr_few_many.predict(X_val)
    y_prob = best_clsfr_few_many.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{abn_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{model_name}_{fold}', log_dir='logs_dd/few_vs_many/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=abn_class_names, epoch_num=0, model_name=f'dd_{model_name}', fold_num=fold, save_dir='figures_dd/few_vs_many/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name=f'dd_{model_name}_average', log_dir='logs_dd/few_vs_many/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9968329374505146, 'val_auc': 0.9893224616579305, 'val_f1': 0.9615384615384616, 'avg_sensitivity': 0.9889584546689962, 'avg_specificity': 0.9889584546689962, 'class_Few_sensitivity': 0.9975247524752475, 'class_Many_sensitivity': 0.9803921568627451, 'class_Few_specificity': 0.9803921568627451, 'class_Many_specificity': 0.9975247524752475, 'class_Few_f1': 0.9888842539199568, 'class_Many_f1': 0.9888842539199568}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 1.0, 'val_auc': 1.0, 'val_f1': 1.0, 'avg_sensitivity': 1.0, 'avg_specificity': 1.0, 'class_Few_sensitivity': 1.0, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 1.0, 'class_Few_f1': 1.0, 'class_Many_f1': 1.0}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9960380348652932, 'val_auc': 0.9987128712871287, 'val_f1': 0.9494949494949495, 'avg_sensitivity': 0.9691749174917492, 'avg_specificity': 0.9691749174917492, 'class_Few_sensitivity': 0.9983498349834984, 'class_Many_sensitivity': 0.94, 'class_Few_specificity': 0.94, 'class_Many_specificity': 0.9983498349834984, 'class_Few_f1': 0.9682966696179254, 'class_Many_f1': 0.9682966696179254}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9960380348652932, 'val_auc': 0.9987953795379537, 'val_f1': 0.9514563106796117, 'avg_sensitivity': 0.9883498349834983, 'avg_specificity': 0.9883498349834983, 'class_Few_sensitivity': 0.9966996699669967, 'class_Many_sensitivity': 0.98, 'class_Few_specificity': 0.98, 'class_Many_specificity': 0.9966996699669967, 'class_Few_f1': 0.9882792934183724, 'class_Many_f1': 0.9882792934183724}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9976228209191759, 'val_auc': 0.9985478547854785, 'val_f1': 0.9702970297029703, 'avg_sensitivity': 0.9891749174917492, 'avg_specificity': 0.9891749174917492, 'class_Few_sensitivity': 0.9983498349834984, 'class_Many_sensitivity': 0.98, 'class_Few_specificity': 0.98, 'class_Many_specificity': 0.9983498349834984, 'class_Few_f1': 0.9890898171626852, 'class_Many_f1': 0.9890898171626852}
# Average results across all folds:
# val_accuracy: 0.9973063656200554
# val_auc: 0.9970757134536983
# val_f1: 0.9665573502831986
# avg_sensitivity: 0.9871316249271986
# avg_specificity: 0.9871316249271986
# class_Few_sensitivity: 0.9981848184818481
# class_Many_sensitivity: 0.9760784313725491
# class_Few_specificity: 0.9760784313725491
# class_Many_specificity: 0.9981848184818481
# class_Few_f1: 0.9869100068237879
# class_Many_f1: 0.9869100068237879

# %%
def combine_predictions(normal_abnormal_pred, few_many_pred):
    # Initialize final_pred with the same shape as normal_abnormal_pred, filled with 2 (Normal)
    final_pred = np.full(normal_abnormal_pred.shape, 2)
    
    # Create a mask where normal_abnormal_pred is 0 (Abnormal)
    abnormal_mask = normal_abnormal_pred == 0
    
    # Update final_pred where the mask is True with values from few_many_pred
    final_pred[abnormal_mask] = few_many_pred
    
    # Return the final combined predictions
    return final_pred

def combine_probabilities(normal_abnormal_prob, few_many_prob, abnormal_mask):
    # Initialize with probabilities for Normal class
    combined_prob = np.column_stack((np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     normal_abnormal_prob[:, 1]))
    
    # Update probabilities for Abnormal (Few and Many) classes
    if few_many_prob.size > 0:
        combined_prob[abnormal_mask, 0] = few_many_prob[:, 0] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 1] = few_many_prob[:, 1] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 2] = 0  # Probability of being Normal for predicted Abnormal samples
    
    # Normalize probabilities
    row_sums = combined_prob.sum(axis=1)
    combined_prob /= row_sums[:, np.newaxis]
    
    return combined_prob

# %%
overall_true = []
overall_pred = []
overall_prob = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Stage 1: Normal vs Abnormal
    y_train_binary = (y_train == 2).astype(int)
    best_clsfr_nor_abn.fit(X_train, y_train_binary)
    y_pred_binary = best_clsfr_nor_abn.predict(X_val)
    y_prob_binary = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Stage 2: Few vs Many (only for predicted Abnormal samples)
    abnormal_mask_train = y_train != 2
    X_train_abnormal = X_train[abnormal_mask_train]
    y_train_abnormal = y_train[abnormal_mask_train]
    
    best_clsfr_few_many.fit(X_train_abnormal, y_train_abnormal)
    
    abnormal_mask_val = y_pred_binary == 0
    X_val_abnormal = X_val[abnormal_mask_val]
    
    if len(X_val_abnormal) > 0:
        y_pred_few_many = best_clsfr_few_many.predict(X_val_abnormal)
        y_prob_few_many = best_clsfr_few_many.predict_proba(X_val_abnormal)
    else:
        y_pred_few_many = np.array([])
        y_prob_few_many = np.array([])
    
    # Combine predictions and probabilities
    y_pred_combined = combine_predictions(y_pred_binary, y_pred_few_many)
    y_prob_combined = combine_probabilities(y_prob_binary, y_prob_few_many, abnormal_mask_val)
    
    overall_true.extend(y_val)
    overall_pred.extend(y_pred_combined)
    overall_prob.extend(y_prob_combined)
    
    # Calculate and log metrics for this fold
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred_combined, y_prob_combined, num_classes=3)
     
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_combined_{model_name}_{fold}', log_dir='logs_dd/combined/')
    print("Metrics for this fold:")
    print(metrics)
    
    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_combined_{model_name}', fold_num=fold, save_dir='figures_dd/combined/')

# Calculate overall metrics
overall_true = np.array(overall_true)
overall_pred = np.array(overall_pred)
overall_prob = np.array(overall_prob)

accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(overall_true, overall_pred, overall_prob, num_classes=3)

overall_metrics = {
    'overall_accuracy': accuracy,
    'overall_auc': auc,
    'overall_f1': f1,
    'overall_avg_sensitivity': avg_sensitivity,
    'overall_avg_specificity': avg_specificity,
    **{f'overall_class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
}

print("Overall metrics:")
for key, value in overall_metrics.items():
    print(f"{key}: {value}")

custom_log(overall_metrics, model_name=f'dd_combined_{model_name}_overall', log_dir='logs_dd/combined/')

# Plot overall confusion matrix
plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_combined_{model_name}_overall', save_dir='figures_dd/combined/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9787965616045845, 'val_auc': 0.9855139926329484, 'val_f1': 0.9789799035717778, 'avg_sensitivity': 0.9877175766208776, 'avg_specificity': 0.9887957033612073, 'class_Few_sensitivity': 0.9743384121892542, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9888143176733781, 'class_Few_specificity': 0.9899598393574297, 'class_Many_specificity': 0.9964580873671782, 'class_None_specificity': 0.9799691833590138, 'class_Few_f1': 0.9820870097004446, 'class_Many_f1': 0.9982259018332348, 'class_None_f1': 0.9843718812921299}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9782234957020057, 'val_auc': 0.9844761119278884, 'val_f1': 0.9784024025439811, 'avg_sensitivity': 0.9874502684145154, 'avg_specificity': 0.9882987683496344, 'class_Few_sensitivity': 0.9735364875701684, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9888143176733781, 'class_Few_specificity': 0.9899598393574297, 'class_Many_specificity': 0.9988193624557261, 'class_None_specificity': 0.9761171032357473, 'class_Few_f1': 0.981679478210807, 'class_Many_f1': 0.9994093325457768, 'class_None_f1': 0.9824246863117455}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9759312320916905, 'val_auc': 0.9831874598271314, 'val_f1': 0.9761566802626747, 'avg_sensitivity': 0.9858949084497685, 'avg_specificity': 0.9874577699532724, 'class_Few_sensitivity': 0.971107544141252, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9865771812080537, 'class_Few_specificity': 0.9899799599198397, 'class_Many_specificity': 0.9970466627288836, 'class_None_specificity': 0.975346687211094, 'class_Few_f1': 0.9804529432123309, 'class_Many_f1': 0.9985211475894705, 'class_None_f1': 0.9809297912713472}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9277936962750717, 'val_auc': 0.9230005739931934, 'val_f1': 0.9274231698554688, 'avg_sensitivity': 0.8731102928062611, 'avg_specificity': 0.9388476258608196, 'class_Few_sensitivity': 0.9582664526484751, 'class_Many_sensitivity': 0.803921568627451, 'class_None_sensitivity': 0.8571428571428571, 'class_Few_specificity': 0.8597194388777555, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9568234387047032, 'class_Few_f1': 0.9063219916131429, 'class_Many_f1': 0.891304347826087, 'class_None_f1': 0.9042443378468638}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9759174311926605, 'val_auc': 0.9841707147107317, 'val_f1': 0.9761385299606643, 'avg_sensitivity': 0.9844603402027428, 'avg_specificity': 0.9859757068771099, 'class_Few_sensitivity': 0.9735152487961477, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9798657718120806, 'class_Few_specificity': 0.9819277108433735, 'class_Many_specificity': 0.9952746603662138, 'class_None_specificity': 0.9807247494217425, 'class_Few_f1': 0.9777033842989101, 'class_Many_f1': 0.9976317347542925, 'class_None_f1': 0.9802950724484679}
# Overall metrics:
# overall_accuracy: 0.967331499312242
# overall_auc: 0.9659391349625198
# overall_f1: 0.9675136186322927
# overall_avg_sensitivity: 0.9637627745366405
# overall_avg_specificity: 0.9778657166121653
# overall_class_Few_sensitivity: 0.9701540436456996
# overall_class_Many_sensitivity: 0.9609375
# overall_class_None_sensitivity: 0.9601967799642218
# overall_class_Few_specificity: 0.9622792937399679
# overall_class_Many_specificity: 0.9975200755786491
# overall_class_None_specificity: 0.9737977805178791
# overall_class_Few_f1: 0.9662006237186351
# overall_class_Many_f1: 0.9788871197203667
# overall_class_None_f1: 0.9669494550765333
