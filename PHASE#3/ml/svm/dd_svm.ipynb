# %%
import os
import json
from metrics import *
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC

# %%
MODEL_NAME= 'svm'

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
# Divide the data into 2 classes only (Normal and Abnormal)
y_binary = np.zeros(y.shape)
y_binary[y != 2] = 0 # Few and Many
y_binary[y == 2] = 1 # None

# Check the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y_binary, return_counts=True))

# Define the new class names
binary_class_names = ["Abormal", "Normal"]
print('Binary class names:')
print(binary_class_names)
# Out:
# Number of samples in each class:
# (array([0., 1.]), array([6488, 2236]))
# Binary class names:
# ['Abormal', 'Normal']

# %%
# Define the parameter grid for SVM
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'class_weight': ['balanced', None]
}

custom_score = custom_score = make_scorer(custom_scorer, greater_is_better=True, 
                           response_method='predict_proba'
                           )

# %%
# Initialize the SVM classifier
svm = SVC(probability=True, random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=svm, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search.fit(X, y_binary)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.7min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 2.0min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.7min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.7min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.5min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.4min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.5min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.3min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.5min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.6min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.8min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 5.8min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.0min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.2min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.1min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.4min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.3min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.7min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 9.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 9.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 9.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 9.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 9.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=12.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=13.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=13.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=14.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=13.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.8min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.9min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=10.8min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=10.7min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=11.0min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=11.1min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.2min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=11.1min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.0min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.7min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.8min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.4min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.9min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.6min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 2.3min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 2.1min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 2.3min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 1.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.2min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=23.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=25.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=24.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=23.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=23.6min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.4min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=10.3min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.7min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.1min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.1min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=10.3min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=10.4min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.4min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=10.5min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=10.9min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.1min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.1min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.1min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.4min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.3min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.7min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 2.5min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 2.7min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.1min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.3min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.0min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 1.9min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.1min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.9min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 9.1min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.3min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 9.3min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 9.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 8.8min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 9.6min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.4min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.3min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.7min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.5min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.1min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.4min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.8min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 2.9min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.4min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.9min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.1min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.2min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.9min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.8min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.2min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.3min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.0min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 1.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.3min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.0min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.0min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.3min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 1.8min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 1.8min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.4min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.4min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.7min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.1min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.4min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.6min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.3min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 2.5min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=10.1min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=10.5min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=10.6min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.3min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time= 9.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.7min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=23.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=24.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=24.7min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=25.3min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=26.9min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=10.8min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.5min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 5.8min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.8min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.5min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 5.7min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.9min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 7.1min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.8min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.5min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.2min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.1min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.4min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.1min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.3min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 6.3min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 7.1min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.8min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.6min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=10.6min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=10.5min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=10.6min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=10.7min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=15.4min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=12.2min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=16.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=12.8min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=17.6min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.2min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=17.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.2min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=18.3min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.7min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.6min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.1min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 1.9min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=12.5min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.1min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.4min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=10.8min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=10.6min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=11.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.4min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=11.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.9min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.1min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=11.4min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.4min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.8min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.5min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=11.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.5min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.1min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.3min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.7min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.7min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.0min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.1min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.7min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.7min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.0min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.6min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.4min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 2.6min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.6min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.5min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.5min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.7min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.8min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 2.9min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.7min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.1min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.7min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.3min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.5min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.5min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.6min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 4.3min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.7min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 5.6min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 1.6min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.9min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 5.9min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 5.9min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.6min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.2min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.5min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.4min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.1min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.5min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.4min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.4min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.6min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.6min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.5min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.4min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 3.0min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.4min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.0min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.1min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.6min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.3min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.4min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.1min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.5min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.6min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.6min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.8min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.6min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.4min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 4.8min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.1min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.4min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.8min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 6.1min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 5.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.3min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 7.9min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 6.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 7.1min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 7.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 3.3min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 3.8min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 3.7min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 3.7min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=22.3min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=23.2min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=22.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=22.8min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.3min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=23.1min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.9min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 1.9min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.6min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.1min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.4min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.0min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.9min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.2min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.6min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=22.0min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.7min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.7min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.9min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.1min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=23.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=23.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=23.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=24.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 1.8min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.0min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.6min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=21.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=22.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=22.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=22.9min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=23.1min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=23.1min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=23.0min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=23.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.3min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.3min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.2min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.1min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=24.1min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.9min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.1min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.2min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.1min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  57.6s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  53.5s
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=SVC(probability=True, random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': ['balanced', None],
#                                         'gamma': ['scale', 'auto', 0.001, 0.01,
#                                                   0.1, 1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save best parameters
with open('dd_normal_vs_abnormal_best_params.json', 'w') as f:
    json.dump(random_search.best_params_, f, indent=4)

# %%
# # Get the best parameters
# best_params = random_search.best_params_
# print("Best parameters:", best_params)

# Load the best parameters from a json file
with open('dd_normal_vs_abnormal_best_params.json', 'r') as f:
    best_params = json.load(f)

# Perform 10-fold cross-validation using the best model
best_clsfr_nor_abn = SVC(**best_params, probability=True, random_state=42)

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y_binary), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y_binary[train_index], y_binary[val_index]
    
    best_clsfr_nor_abn.fit(X_train, y_train)
    y_pred = best_clsfr_nor_abn.predict(X_val)
    y_prob = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{binary_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{binary_class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_nor_abn', log_dir='logs_dd/nor_vs_abn/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=binary_class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_nor_abn', fold_num=fold, save_dir='figures_dd/nor_vs_abn/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name=f'dd_{MODEL_NAME}_nor_abn_average', log_dir='logs_dd/nor_vs_abn/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9799426934097422, 'val_auc': 0.9930300617366935, 'val_f1': 0.9609810479375697, 'avg_sensitivity': 0.9747839560431985, 'avg_specificity': 0.9747839560431985, 'class_Abormal_sensitivity': 0.985362095531587, 'class_Normal_sensitivity': 0.9642058165548099, 'class_Abormal_specificity': 0.9642058165548099, 'class_Normal_specificity': 0.985362095531587, 'class_Abormal_f1': 0.9746691644174827, 'class_Normal_f1': 0.9746691644174827}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9724928366762178, 'val_auc': 0.9944157764656001, 'val_f1': 0.9478260869565217, 'avg_sensitivity': 0.9734430529846296, 'avg_specificity': 0.9734430529846296, 'class_Abormal_sensitivity': 0.9714946070878274, 'class_Normal_sensitivity': 0.9753914988814317, 'class_Abormal_specificity': 0.9753914988814317, 'class_Normal_specificity': 0.9714946070878274, 'class_Abormal_f1': 0.973439152970755, 'class_Normal_f1': 0.973439152970755}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9753581661891118, 'val_auc': 0.9969769357779824, 'val_f1': 0.9529025191675794, 'avg_sensitivity': 0.9746357328259274, 'avg_specificity': 0.9746357328259274, 'class_Abormal_sensitivity': 0.9761171032357473, 'class_Normal_sensitivity': 0.9731543624161074, 'class_Abormal_specificity': 0.9731543624161074, 'class_Normal_specificity': 0.9761171032357473, 'class_Abormal_f1': 0.9746334812582726, 'class_Normal_f1': 0.9746334812582726}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9696275071633238, 'val_auc': 0.9922589216874106, 'val_f1': 0.9414364640883978, 'avg_sensitivity': 0.9634957732129089, 'avg_specificity': 0.9634957732129089, 'class_Abormal_sensitivity': 0.9760986892829607, 'class_Normal_sensitivity': 0.9508928571428571, 'class_Abormal_specificity': 0.9508928571428571, 'class_Normal_specificity': 0.9760986892829607, 'class_Abormal_f1': 0.9633309219516116, 'class_Normal_f1': 0.9633309219516116}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.974197247706422, 'val_auc': 0.9925701886473518, 'val_f1': 0.9506037321624589, 'avg_sensitivity': 0.9723893893842097, 'avg_specificity': 0.9723893893842097, 'class_Abormal_sensitivity': 0.9760986892829607, 'class_Normal_sensitivity': 0.9686800894854586, 'class_Abormal_specificity': 0.9686800894854586, 'class_Normal_specificity': 0.9760986892829607, 'class_Abormal_f1': 0.9723752397998054, 'class_Normal_f1': 0.9723752397998054}
# Average results across all folds:
# val_accuracy: 0.9743236902289635
# val_auc: 0.9938503768630076
# val_f1: 0.9507499700625056
# avg_sensitivity: 0.9717495808901748
# avg_specificity: 0.9717495808901748
# class_Abormal_sensitivity: 0.9770342368842166
# class_Normal_sensitivity: 0.9664649248961329
# class_Abormal_specificity: 0.9664649248961329
# class_Normal_specificity: 0.9770342368842166
# class_Abormal_f1: 0.9716895920795855
# class_Normal_f1: 0.9716895920795855

# %%
# Predict the class Abnormal for each sample using the best model from the first stage
y_pred = best_clsfr_nor_abn.predict(X)
abnormal_indices = np.where(y_pred == 0)[0]
print(f"Number of predicted abnormal samples: {len(abnormal_indices)}")
# Out:
# Number of predicted abnormal samples: 6413

# %%
# Filter the dataset to include only the predicted Abnormal sample
X_pred_abnormal = X[abnormal_indices]
y_pred_abnormal = y[abnormal_indices]

# Check the number of samples in each class
print('Number of samples in each class:')
len(y_pred_abnormal), len(X_pred_abnormal)
# Out:
# Number of samples in each class:
# (6413, 6413)

# %%
print(np.unique(y_pred_abnormal, return_counts=True))
normal_in_abnormal = y_pred_abnormal == 2  # 2 is the label for Normal
len(y_pred_abnormal[normal_in_abnormal])
# Out:
# (array([0, 1, 2]), array([6106,  253,   54]))
# 54

# %%
X_abnormal = X_pred_abnormal[~normal_in_abnormal]
y_abnormal = y_pred_abnormal[~normal_in_abnormal]

# Check the number of samples in each class
print('Number of samples in each class:')
np.unique(y_abnormal, return_counts=True)
# Out:
# Number of samples in each class:
# (array([0, 1]), array([6106,  253]))

# %%
# Initialize RandomizedSearchCV
random_search_abn = RandomizedSearchCV(
    estimator=svm, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search_abn.fit(X_abnormal, y_abnormal)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.1s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   7.4s[CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   7.4s
#
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.6s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.8s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   7.9s
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time=   8.6s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   6.0s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   6.4s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=   6.2s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  26.4s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  31.6s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  47.9s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  48.9s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  50.9s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  43.0s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  51.3s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   6.9s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  48.9s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.1s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.4s
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time=  59.4s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   8.0s
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time=   7.7s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  50.9s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  57.3s
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time=  57.3s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  32.1s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  25.8s
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  33.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  32.2s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  39.5s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  59.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  59.6s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  43.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  27.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time=  39.0s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.5min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  58.2s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time= 1.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  20.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  24.2s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  44.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  14.7s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  26.0s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  43.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time=  33.2s
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=  59.0s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  44.7s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  32.6s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  34.0s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  35.4s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  40.5s
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time=  44.7s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  37.7s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  25.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  26.5s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  26.7s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  39.3s
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time=  44.9s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  42.3s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  23.4s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time=  44.9s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  46.4s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  19.6s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  42.4s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  53.0s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  17.7s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  13.3s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  40.9s
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=  54.8s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time=  25.0s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  38.7s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  37.8s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  34.2s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  43.3s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  34.8s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time=  53.6s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  35.2s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  21.4s
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 1.0min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  26.4s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  33.0s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  27.5s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  36.9s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  16.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.4min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  23.5s
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time=  28.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.6min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  22.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.5min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  14.2s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  45.1s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  43.4s
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time=  42.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.8min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  16.1s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 5.9min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  18.0s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  13.4s
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time=  16.3s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  21.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  24.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  27.2s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  30.8s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time=  39.6s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.1min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.7min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.8min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.8min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=  10.7s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   8.4s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=  10.9s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=   8.8s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time=  10.4s
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.3min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.3min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=  59.6s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.2min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  25.2s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 6.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  27.1s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  30.7s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  32.0s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.4min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  20.0s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.4min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 7.6min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  37.2s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  32.7s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  26.4s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  30.9s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  12.4s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  31.9s
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time=  31.8s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  28.7s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  14.0s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.2min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  11.7s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  15.3s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  29.2s
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time=  16.0s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  34.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time=  34.6s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   7.7s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time= 8.3min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   7.8s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   8.4s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   9.2s
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time=   8.8s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  10.6s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=   9.5s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  11.2s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  11.6s
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time=  12.5s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=  10.4s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=  10.3s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   9.9s
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.5min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   8.6s
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time=   9.3s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  11.9s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  14.4s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  11.7s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=   9.6s
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time=  15.6s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  30.0s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  31.6s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  26.7s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  26.0s
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time=  23.4s
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  42.7s
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  45.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.8min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  44.8s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.1min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  27.4s
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.4min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  42.3s
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=  44.0s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  27.2s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  23.6s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  22.6s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  34.3s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  22.5s
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time=  35.2s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  26.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  16.9s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time=  26.2s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.1s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   8.2s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   8.5s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   9.3s
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   6.8s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  43.6s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  11.4s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  10.4s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  45.8s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  53.7s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  48.1s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  12.1s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=  44.6s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  12.4s
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time=  11.7s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  11.6s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  12.9s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  13.0s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  14.5s
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time=  14.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  48.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  49.8s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  50.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  55.2s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time=  58.4s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  45.1s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  44.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.6min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.8min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  40.6s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  45.8s
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  52.5s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.1min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  50.0s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  43.6s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  45.0s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  43.7s
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=  52.7s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.3min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time= 8.9min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  18.2s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  21.4s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time= 1.1min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  23.9s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  15.7s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  59.4s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time=  19.9s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  50.6s
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  54.0s
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.4min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time= 3.2min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=  52.3s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  23.3s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  30.2s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  28.7s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  22.3s
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time=  34.7s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  51.5s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  48.3s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  49.7s
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  54.8s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 2.2min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=  40.6s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  50.9s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  50.4s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  48.4s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 3.5min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  50.5s
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=  49.0s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  30.5s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 4.1min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 4.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  32.8s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.3min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  39.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  26.8s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=  36.7s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  29.1s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  32.4s
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 4.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  34.4s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  19.5s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  24.7s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  17.9s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  19.5s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  19.4s
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time=  24.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time=  44.0s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  25.2s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  27.3s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  27.3s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  34.1s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  27.0s
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=  32.7s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  25.0s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  13.9s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  11.3s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  13.4s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  11.4s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  28.3s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  25.2s
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time=  15.4s
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time=  30.6s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   6.4s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   8.3s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   8.9s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   7.6s
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time=   7.2s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  25.0s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  21.4s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  32.7s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  29.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time=  30.0s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  22.4s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.2s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  24.5s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.7s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.6s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.1s
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time=  14.8s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  42.2s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  41.1s
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time=  51.5s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  38.2s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  47.9s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  51.6s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 7.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   7.0s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  49.6s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   6.4s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  36.9s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 7.2min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   9.0s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time=  59.3s
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   6.3s
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 1.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time=   8.3s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  43.1s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  20.9s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  54.4s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  19.5s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time=  36.3s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  26.9s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  25.7s
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time=  28.4s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   8.0s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   7.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  25.5s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  26.7s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   8.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  29.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  28.6s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   6.8s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=   9.3s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   8.5s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   9.3s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   7.6s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   8.5s
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time=   8.9s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  11.6s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  12.0s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  12.4s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  13.6s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time=  13.2s
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time=  28.3s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   4.8s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.7s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.1s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   5.7s
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time=   7.4s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  21.8s
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time= 8.1min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  22.8s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  24.9s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  28.2s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  19.1s
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time=  34.8s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  30.4s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  19.2s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  26.3s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  30.0s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  20.5s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  19.9s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  29.8s
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time=  32.1s
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time=  21.5s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  18.3s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  17.9s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  20.3s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  20.7s
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time=  13.0s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 6.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 6.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 7.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 7.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 7.8min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.0min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  50.2s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.0min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  22.0s
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.0min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.1min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time= 9.2min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  24.4s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  17.0s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  27.5s
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time=  33.2s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time=  59.4s
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.0min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   8.7s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   9.2s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  33.1s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  33.3s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   8.9s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=  10.1s
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time=   8.7s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  35.7s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   7.6s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   7.7s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  35.8s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time=  30.2s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   9.3s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   8.2s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=   7.2s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   5.7s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   5.7s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   6.9s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   6.3s
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time=   7.5s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   7.2s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   6.9s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   7.6s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   6.1s
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time=   9.0s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   9.7s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   9.5s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   9.3s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   7.6s
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time=   9.5s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.3min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.6min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 3.9min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  21.9s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  24.8s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=12.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  30.4s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 3.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  17.7s
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time=  34.7s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  19.0s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  28.6s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  33.6s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  29.9s
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  29.4s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.8min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  36.3s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  32.0s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  13.8s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  36.5s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  36.9s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.4min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  11.9s
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time=  31.8s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  14.7s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  10.7s
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time=  14.8s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  17.9s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  23.8s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  16.9s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  23.0s
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time=  21.2s
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time= 4.0min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  18.0s
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=11.6min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  15.9s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  16.5s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  22.5s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  23.5s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time=  23.2s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  24.8s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  23.9s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  20.2s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  20.9s
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time= 9.8min
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=SVC(probability=True, random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': ['balanced', None],
#                                         'gamma': ['scale', 'auto', 0.001, 0.01,
#                                                   0.1, 1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save best parameters few vs many
with open('dd_few_vs_many_best_params.json', 'w') as f:
    json.dump(random_search_abn.best_params_, f, indent=4)

# %%
# Load the best parameters from a json file
with open('dd_few_vs_many_best_params.json', 'r') as f:
    best_params_abn = json.load(f)

best_clsfr_few_many = SVC(**best_params_abn, probability=True, random_state=42)

abn_class_names = ["Few", "Many"]

# %%
fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X_abnormal, y_abnormal), 1):
    print(f"Fold {fold}")
    X_train, X_val = X_abnormal[train_index], X_abnormal[val_index]
    y_train, y_val = y_abnormal[train_index], y_abnormal[val_index]
    
    best_clsfr_few_many.fit(X_train, y_train)
    y_pred = best_clsfr_few_many.predict(X_val)
    y_prob = best_clsfr_few_many.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob, num_classes=2)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{abn_class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{abn_class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_few_many', log_dir='logs_dd/few_vs_many/')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=abn_class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_few_many', fold_num=fold, save_dir='figures_dd/few_vs_many/')
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items(): 
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name=f'dd_{MODEL_NAME}_few_many_average', log_dir='logs_dd/few_vs_many/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9937106918238994, 'val_auc': 0.9985924713584288, 'val_f1': 0.9230769230769231, 'avg_sensitivity': 0.977545008183306, 'avg_specificity': 0.977545008183306, 'class_Few_sensitivity': 0.9950900163666121, 'class_Many_sensitivity': 0.96, 'class_Few_specificity': 0.96, 'class_Many_specificity': 0.9950900163666121, 'class_Few_f1': 0.9772301098312349, 'class_Many_f1': 0.9772301098312349}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9976415094339622, 'val_auc': 0.9991649403414109, 'val_f1': 0.9702970297029703, 'avg_sensitivity': 0.9799826564532448, 'avg_specificity': 0.9799826564532448, 'class_Few_sensitivity': 0.9991809991809992, 'class_Many_sensitivity': 0.9607843137254902, 'class_Few_specificity': 0.9607843137254902, 'class_Many_specificity': 0.9991809991809992, 'class_Few_f1': 0.9796065514670338, 'class_Many_f1': 0.9796065514670338}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9984276729559748, 'val_auc': 0.9999518234812353, 'val_f1': 0.9807692307692307, 'avg_sensitivity': 0.9991809991809992, 'avg_specificity': 0.9991809991809992, 'class_Few_sensitivity': 0.9983619983619983, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 0.9983619983619983, 'class_Few_f1': 0.9991803278688524, 'class_Many_f1': 0.9991803278688524}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9984276729559748, 'val_auc': 0.99935764641647, 'val_f1': 0.9807692307692307, 'avg_sensitivity': 0.9991809991809992, 'avg_specificity': 0.9991809991809992, 'class_Few_sensitivity': 0.9983619983619983, 'class_Many_sensitivity': 1.0, 'class_Few_specificity': 1.0, 'class_Many_specificity': 0.9983619983619983, 'class_Few_f1': 0.9991803278688524, 'class_Many_f1': 0.9991803278688524}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.996852871754524, 'val_auc': 0.9835708435708437, 'val_f1': 0.96, 'avg_sensitivity': 0.9791809991809992, 'avg_specificity': 0.9791809991809992, 'class_Few_sensitivity': 0.9983619983619983, 'class_Many_sensitivity': 0.96, 'class_Few_specificity': 0.96, 'class_Many_specificity': 0.9983619983619983, 'class_Few_f1': 0.9788052660633332, 'class_Many_f1': 0.9788052660633332}
# Average results across all folds:
# val_accuracy: 0.997012083784867
# val_auc: 0.9961275450336778
# val_f1: 0.962982482863671
# avg_sensitivity: 0.9870141324359096
# avg_specificity: 0.9870141324359096
# class_Few_sensitivity: 0.9978714021267212
# class_Many_sensitivity: 0.976156862745098
# class_Few_specificity: 0.976156862745098
# class_Many_specificity: 0.9978714021267212
# class_Few_f1: 0.9868005166198615
# class_Many_f1: 0.9868005166198615

# %%
def combine_predictions(normal_abnormal_pred, few_many_pred):
    # Initialize final_pred with the same shape as normal_abnormal_pred, filled with 2 (Normal)
    final_pred = np.full(normal_abnormal_pred.shape, 2)
    
    # Create a mask where normal_abnormal_pred is 0 (Abnormal)
    abnormal_mask = normal_abnormal_pred == 0
    
    # Update final_pred where the mask is True with values from few_many_pred
    final_pred[abnormal_mask] = few_many_pred
    
    # Return the final combined predictions
    return final_pred

def combine_probabilities(normal_abnormal_prob, few_many_prob, abnormal_mask):
    # Initialize with probabilities for Normal class
    combined_prob = np.column_stack((np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     np.zeros_like(normal_abnormal_prob[:, 0]), 
                                     normal_abnormal_prob[:, 1]))
    
    # Update probabilities for Abnormal (Few and Many) classes
    if few_many_prob.size > 0:
        combined_prob[abnormal_mask, 0] = few_many_prob[:, 0] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 1] = few_many_prob[:, 1] * normal_abnormal_prob[abnormal_mask, 0]
        combined_prob[abnormal_mask, 2] = 0  # Probability of being Normal for predicted Abnormal samples
    
    # Normalize probabilities
    row_sums = combined_prob.sum(axis=1)
    combined_prob /= row_sums[:, np.newaxis]
    
    return combined_prob

# %%
overall_true = []
overall_pred = []
overall_prob = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    # Stage 1: Normal vs Abnormal
    y_train_binary = (y_train == 2).astype(int)
    best_clsfr_nor_abn.fit(X_train, y_train_binary)
    y_pred_binary = best_clsfr_nor_abn.predict(X_val)
    y_prob_binary = best_clsfr_nor_abn.predict_proba(X_val)
    
    # Stage 2: Few vs Many (only for predicted Abnormal samples)
    abnormal_mask_train = y_train != 2
    X_train_abnormal = X_train[abnormal_mask_train]
    y_train_abnormal = y_train[abnormal_mask_train]
    
    best_clsfr_few_many.fit(X_train_abnormal, y_train_abnormal)
    
    abnormal_mask_val = y_pred_binary == 0
    X_val_abnormal = X_val[abnormal_mask_val]
    
    if len(X_val_abnormal) > 0:
        y_pred_few_many = best_clsfr_few_many.predict(X_val_abnormal)
        y_prob_few_many = best_clsfr_few_many.predict_proba(X_val_abnormal)
    else:
        y_pred_few_many = np.array([])
        y_prob_few_many = np.array([])
    
    # Combine predictions and probabilities
    y_pred_combined = combine_predictions(y_pred_binary, y_pred_few_many)
    y_prob_combined = combine_probabilities(y_prob_binary, y_prob_few_many, abnormal_mask_val)
    
    overall_true.extend(y_val)
    overall_pred.extend(y_pred_combined)
    overall_prob.extend(y_prob_combined)
    
    # Calculate and log metrics for this fold
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred_combined, y_prob_combined, num_classes=3)
     
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
    }
    
    custom_log(metrics, model_name=f'dd_{MODEL_NAME}_combined', log_dir='logs_dd/combined/')
    print("Metrics for this fold:")
    print(metrics)
    
    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_combined', fold_num=fold, save_dir='figures_dd/combined/')

# Calculate overall metrics
overall_true = np.array(overall_true)
overall_pred = np.array(overall_pred)
overall_prob = np.array(overall_prob)

accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(overall_true, overall_pred, overall_prob, num_classes=3)

overall_metrics = {
    'overall_accuracy': accuracy,
    'overall_auc': auc,
    'overall_f1': f1,
    'overall_avg_sensitivity': avg_sensitivity,
    'overall_avg_specificity': avg_specificity,
    **{f'overall_class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
    **{f'overall_class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
}

print("Overall metrics:")
for key, value in overall_metrics.items():
    print(f"{key}: {value}")

custom_log(overall_metrics, model_name=f'dd_{MODEL_NAME}_combined_overall', log_dir='logs_dd/combined/')

# Plot overall confusion matrix
plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name=f'dd_{MODEL_NAME}_combined_overall', save_dir='figures_dd/combined/')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9793696275071633, 'val_auc': 0.9862910267121973, 'val_f1': 0.9795642794757913, 'avg_sensitivity': 0.9889416927247318, 'avg_specificity': 0.9898775861053322, 'class_Few_sensitivity': 0.9735364875701684, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9932885906040269, 'class_Few_specificity': 0.9939759036144579, 'class_Many_specificity': 0.9964580873671782, 'class_None_specificity': 0.9791987673343605, 'class_Few_f1': 0.9836500286044702, 'class_Many_f1': 0.9982259018332348, 'class_None_f1': 0.9861933559293599}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9810888252148997, 'val_auc': 0.9868681995608959, 'val_f1': 0.9812240959671334, 'avg_sensitivity': 0.9892652133950713, 'avg_specificity': 0.9900553661761823, 'class_Few_sensitivity': 0.9767441860465116, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9910514541387024, 'class_Few_specificity': 0.9919678714859438, 'class_Many_specificity': 0.9982290436835891, 'class_None_specificity': 0.9799691833590138, 'class_Few_f1': 0.9842971677973339, 'class_Many_f1': 0.9991137370753324, 'class_None_f1': 0.9854791631324993}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9799426934097422, 'val_auc': 0.9859723449204291, 'val_f1': 0.9800985248326024, 'avg_sensitivity': 0.9877675676257986, 'avg_specificity': 0.9892554073441303, 'class_Few_sensitivity': 0.9767255216693419, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9865771812080537, 'class_Few_specificity': 0.9899799599198397, 'class_Many_specificity': 0.9970466627288836, 'class_None_specificity': 0.9807395993836672, 'class_Few_f1': 0.98330807723541, 'class_Many_f1': 0.9985211475894705, 'class_None_f1': 0.9836497294228652}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9358166189111747, 'val_auc': 0.9291669951757855, 'val_f1': 0.935272476080642, 'avg_sensitivity': 0.8782851857971653, 'avg_specificity': 0.9436786706283294, 'class_Few_sensitivity': 0.9670947030497592, 'class_Many_sensitivity': 0.803921568627451, 'class_None_sensitivity': 0.8638392857142857, 'class_Few_specificity': 0.8657314629258517, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9653045489591364, 'class_Few_f1': 0.913610169476652, 'class_Many_f1': 0.891304347826087, 'class_None_f1': 0.9117577046295992}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9793577981651376, 'val_auc': 0.9859953413137392, 'val_f1': 0.9795291060582453, 'avg_sensitivity': 0.9855872872236646, 'avg_specificity': 0.9871053862215758, 'class_Few_sensitivity': 0.9791332263242376, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9776286353467561, 'class_Few_specificity': 0.9799196787148594, 'class_Many_specificity': 0.9952746603662138, 'class_None_specificity': 0.9861218195836546, 'class_Few_f1': 0.9795262946607789, 'class_Many_f1': 0.9976317347542925, 'class_None_f1': 0.9818568610331821}
# Overall metrics:
# overall_accuracy: 0.9711141678129298
# overall_auc: 0.9689543505980058
# overall_f1: 0.9712396598722254
# overall_avg_sensitivity: 0.9660057997444088
# overall_avg_specificity: 0.9799850897084582
# overall_class_Few_sensitivity: 0.9746469833119383
# overall_class_Many_sensitivity: 0.9609375
# overall_class_None_sensitivity: 0.962432915921288
# overall_class_Few_specificity: 0.9642857142857143
# overall_class_Many_specificity: 0.997401983939537
# overall_class_None_specificity: 0.9782675709001233
# overall_class_Few_f1: 0.9694386645228412
# overall_class_Many_f1: 0.9788302557366917
# overall_class_None_f1: 0.9702856439786961
