# %%
import os
import json
from metrics import *
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.svm import SVC

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
os.makedirs('logs', exist_ok=True)
os.makedirs('figures', exist_ok=True)

# %%
def custom_scorer(y_true, y_pred):
    # If y_pred is probabilities, convert to class predictions
    if y_pred.ndim == 2:
        y_pred_class = np.argmax(y_pred, axis=1)
    else:
        y_pred_class = y_pred

    # Calculate metrics
    auc = roc_auc_score(y_true, y_pred, average='macro', multi_class='ovo')
    f1 = f1_score(y_true, y_pred_class, average='macro')
    kappa = cohen_kappa_score(y_true, y_pred_class)
    balanced_acc = balanced_accuracy_score(y_true, y_pred_class)
    
    return 0.3 * auc + 0.3 * f1 + 0.2 * kappa + 0.2 * balanced_acc

custom_score = make_scorer(custom_scorer, greater_is_better=True, needs_proba=True)
# Out:
# /home/samo/dev/liver/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV

# Define the parameter grid for SVM
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto', 0.001, 0.01, 0.1, 1],
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'class_weight': ['balanced', None]
}

# Initialize the SVM classifier
svm = SVC(probability=True, random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=svm, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.0min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=0.1, kernel=linear; total time= 1.9min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time=  58.2s
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ..C=1, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 4.4min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 4.4min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 4.5min
# [CV] END ......C=0.1, class_weight=None, gamma=1, kernel=rbf; total time= 4.7min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 1.3min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.0min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.2min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.1min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.5min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.4min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 1.5min
# [CV] END .C=10, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.2min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.4min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.3min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.9min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.2min
# [CV] END ..C=100, class_weight=None, gamma=0.001, kernel=rbf; total time= 2.6min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.1min
# [CV] END ...C=10, class_weight=None, gamma=1, kernel=sigmoid; total time= 8.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 3.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 4.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 3.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=10.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.7min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=13.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=poly; total time=12.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=16.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time=18.4min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 1.0min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=linear; total time= 2.8min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.1min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.5min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.7min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 5.9min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.2min
# [CV] END ....C=1, class_weight=None, gamma=auto, kernel=poly; total time=12.8min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.2min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 6.1min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 6.3min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 2.1min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.7min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.5min
# [CV] END .C=1, class_weight=balanced, gamma=0.1, kernel=poly; total time= 5.2min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.9min
# [CV] END ..C=1, class_weight=balanced, gamma=0.1, kernel=rbf; total time= 3.4min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 1.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=rbf; total time= 3.5min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.6min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=29.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.7min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf; total time=31.8min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.7min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.1min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 2.4min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.0min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.2min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.1min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=11.9min
# [CV] END ....C=1, class_weight=balanced, gamma=1, kernel=rbf; total time= 4.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.9min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.3min
# [CV] END ..C=0.1, class_weight=None, gamma=auto, kernel=poly; total time=12.2min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 1.3min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 4.0min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 4.0min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 3.9min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.8min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.1min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.4min
# [CV] END .C=1, class_weight=balanced, gamma=1, kernel=linear; total time= 3.2min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 1.3min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.3min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.3min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.5min
# [CV] END ..C=10, class_weight=balanced, gamma=1, kernel=poly; total time= 3.5min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.3min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.3min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 1.3min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.2min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.3min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.6min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.4min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 8.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 7.2min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 8.0min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.2min
# [CV] END C=1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 8.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 1.6min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.4min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=linear; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.2min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 6.4min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.0min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.4min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=11.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=11.4min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=10.1min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=12.0min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 1.8min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=29.6min
# [CV] END .......C=10, class_weight=None, gamma=1, kernel=rbf; total time= 3.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=poly; total time=11.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=poly; total time=30.7min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.8min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 1.5min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.8min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.5min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.1min
# [CV] END C=10, class_weight=balanced, gamma=0.1, kernel=poly; total time= 4.0min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.2min
# [CV] END .C=100, class_weight=balanced, gamma=1, kernel=poly; total time= 3.7min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.6min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.9min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 2.9min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.2min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 1.1min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 3.8min
# [CV] END .....C=1, class_weight=None, gamma=0.1, kernel=poly; total time= 4.0min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.1min
# [CV] END .C=100, class_weight=None, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.1min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time=10.0min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 9.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time=10.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 9.9min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 1.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time=10.2min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.3min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 1.3min
# [CV] END ....C=10, class_weight=None, gamma=0.01, kernel=rbf; total time= 2.3min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.8min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.5min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.8min
# [CV] END ......C=10, class_weight=None, gamma=1, kernel=poly; total time= 2.6min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 1.9min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.4min
# [CV] END ..C=100, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.2min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.4min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 1.5min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.3min
# [CV] END C=10, class_weight=balanced, gamma=0.01, kernel=rbf; total time= 3.3min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.3min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.7min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.4min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 1.1min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.3min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.6min
# [CV] END ...C=1, class_weight=None, gamma=0.001, kernel=poly; total time=11.2min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=poly; total time= 2.6min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.3min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.1min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.4min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.2min
# [CV] END C=10, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.0min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=31.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.3min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.1min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=11.7min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=12.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=32.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=33.1min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.2min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=sigmoid; total time=12.2min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf; total time=33.7min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 5.8min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.4min
# [CV] END ...C=0.1, class_weight=None, gamma=0.1, kernel=poly; total time= 6.8min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.9min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.3min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.6min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 6.4min
# [CV] END ..C=100, class_weight=None, gamma=0.01, kernel=poly; total time= 7.0min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 5.7min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.4min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.7min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.6min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.4min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.3min
# [CV] END C=1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=rbf; total time= 7.6min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.6min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.8min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.9min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.7min
# [CV] END ...C=10, class_weight=None, gamma=auto, kernel=poly; total time=11.6min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.7min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=14.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.6min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=14.0min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=21.8min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=21.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.5min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=22.3min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.2min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=22.4min
# [CV] END C=1, class_weight=balanced, gamma=auto, kernel=sigmoid; total time=22.3min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=1, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.0min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.6min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.3min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.8min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.8min
# [CV] END ...C=0.1, class_weight=None, gamma=auto, kernel=rbf; total time=13.9min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.1min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=11.2min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.3min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.5min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=10.6min
# [CV] END C=1, class_weight=balanced, gamma=scale, kernel=sigmoid; total time=11.0min
# [CV] END C=100, class_weight=balanced, gamma=0.1, kernel=sigmoid; total time= 5.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.6min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 2.2min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=11.7min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.7min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.1min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.4min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.1min
# [CV] END ..C=0.1, class_weight=None, gamma=0.01, kernel=poly; total time=12.1min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 2.0min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear; total time= 3.7min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.1min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=11.8min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.1min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=12.7min
# [CV] END C=0.1, class_weight=None, gamma=auto, kernel=sigmoid; total time=13.1min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.0min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 1.2min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.3min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 4.1min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.6min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.9min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 1.7min
# [CV] END C=100, class_weight=balanced, gamma=0.01, kernel=sigmoid; total time= 2.7min
# [CV] END ....C=0.1, class_weight=None, gamma=0.1, kernel=rbf; total time= 3.9min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 1.1min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.1min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.1min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.1min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END ......C=100, class_weight=None, gamma=1, kernel=rbf; total time= 3.1min
# [CV] END .C=100, class_weight=None, gamma=0.1, kernel=linear; total time= 2.2min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 1.3min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 3.1min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.9min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=rbf; total time= 2.9min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 2.4min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.2min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.1min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.2min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 1.7min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.3min
# [CV] END .C=0.1, class_weight=None, gamma=scale, kernel=poly; total time= 3.1min
# [CV] END C=10, class_weight=None, gamma=scale, kernel=sigmoid; total time= 2.1min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.1min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.7min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.7min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.8min
# [CV] END .....C=1, class_weight=None, gamma=0.01, kernel=rbf; total time= 3.8min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.9min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 1.1min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.5min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 6.4min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.8min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 4.1min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.4min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.2min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.1min
# [CV] END ....C=1, class_weight=None, gamma=1, kernel=sigmoid; total time= 7.2min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 1.2min
# [CV] END .....C=0.1, class_weight=None, gamma=1, kernel=poly; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly; total time= 5.8min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.6min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END C=10, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.4min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.1min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time=  51.9s
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.7min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.7min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 2.9min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.8min
# [CV] END C=10, class_weight=None, gamma=0.001, kernel=linear; total time= 1.7min
# [CV] END ........C=1, class_weight=None, gamma=1, kernel=rbf; total time= 3.0min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 1.0min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 1.6min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=None, gamma=0.01, kernel=linear; total time= 2.3min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.3min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.2min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=linear; total time= 2.4min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.0min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.8min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.9min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 2.0min
# [CV] END C=100, class_weight=None, gamma=0.01, kernel=sigmoid; total time= 1.8min
# [CV] END .C=0.1, class_weight=balanced, gamma=1, kernel=poly; total time= 3.0min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 1.9min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.2min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.6min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END ...C=10, class_weight=balanced, gamma=1, kernel=rbf; total time= 3.3min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.3min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.4min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.0min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.5min
# [CV] END C=10, class_weight=None, gamma=auto, kernel=sigmoid; total time= 5.5min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.9min
# [CV] END C=100, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=16.7min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=17.6min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=16.4min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=16.9min
# [CV] END C=10, class_weight=balanced, gamma=1, kernel=sigmoid; total time=17.0min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.5min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.8min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=29.9min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.1min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 4.6min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=29.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=30.3min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=sigmoid; total time=29.5min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 1.2min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=0.001, kernel=linear; total time= 2.7min
# [CV] END C=0.1, class_weight=None, gamma=scale, kernel=sigmoid; total time= 5.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.5min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.8min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.3min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.2min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear; total time= 3.6min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time=  53.5s
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END C=0.1, class_weight=None, gamma=0.001, kernel=linear; total time= 2.3min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.9min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.7min
# [CV] END .C=10, class_weight=None, gamma=auto, kernel=linear; total time= 1.8min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.2min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 1.5min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.1min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.2min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.8min
# [CV] END ....C=10, class_weight=None, gamma=0.1, kernel=poly; total time= 2.1min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.9min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.1min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.8min
# [CV] END ..C=10, class_weight=None, gamma=scale, kernel=poly; total time= 1.8min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 1.0min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.1min
# [CV] END .....C=10, class_weight=None, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=34.7min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=34.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=35.1min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=34.8min
# [CV] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly; total time=35.5min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.8min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.7min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 1.1min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.0min
# [CV] END C=10, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.6min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.0min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.9min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.6min
# [CV] END .C=10, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 2.0min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=26.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.7min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=27.0min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.6min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=25.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 2.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 3.5min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=27.3min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.2min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 1.1min
# [CV] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear; total time= 4.0min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.5min
# [CV] END C=100, class_weight=None, gamma=auto, kernel=linear; total time= 2.3min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 1.2min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=34.7min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.8min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 3.0min
# [CV] END C=100, class_weight=balanced, gamma=scale, kernel=poly; total time= 2.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=34.9min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.1min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=35.4min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=34.9min
# [CV] END C=0.1, class_weight=balanced, gamma=0.001, kernel=poly; total time=35.9min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.9min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 2.8min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  53.1s
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.5min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.0min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time= 1.2min
# [CV] END C=100, class_weight=None, gamma=0.1, kernel=sigmoid; total time=  58.0s
# [CV] END ...C=1, class_weight=balanced, gamma=1, kernel=poly; total time= 1.7min
# [CV] END C=1, class_weight=balanced, gamma=0.01, kernel=poly; total time=24.2min
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=SVC(probability=True, random_state=42), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10, 100],
#                                         'class_weight': ['balanced', None],
#                                         'gamma': ['scale', 'auto', 0.001, 0.01,
#                                                   0.1, 1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42,
#                    scoring=make_scorer(custom_scorer, response_method='predict_proba'),
#                    verbose=2)

# %%
# Save the best model
with open('best_model.json', 'w') as f:
    json.dump(random_search.best_params_, f)

# %%
# Get the best parameters
best_params = random_search.best_params_
print("Best parameters:", best_params)

# # Load the best parameters from a json file
# with open('svm_optimized_best_params.json', 'r') as f:
#     best_params = json.load(f)

# Now, let's perform a final 10-fold cross-validation using the best model
best_svm = SVC(**best_params, probability=True, random_state=42)

fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    best_svm.fit(X_train, y_train)
    y_pred = best_svm.predict(X_val)
    y_prob = best_svm.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob)
    
    # Calculate AUC for double dichotomy
    double_dichotomy_auc = calculate_double_dichotomy_auc(y_val, y_prob)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
        **double_dichotomy_auc
    }
    
    custom_log(metrics, model_name=f'svm_optimized_{fold}', log_dir='logs')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name='svm_optimized', fold_num=fold)
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items():
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name='svm_optimized_average', log_dir='logs')
# Out:
# Best parameters: {'kernel': 'rbf', 'gamma': 0.1, 'class_weight': 'balanced', 'C': 1}
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9805157593123209, 'val_auc': 0.9981881258560373, 'val_f1': 0.9806749571747311, 'avg_sensitivity': 0.9885195012399631, 'avg_specificity': 0.9895661193858606, 'class_Few_sensitivity': 0.9767441860465116, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9888143176733781, 'class_Few_specificity': 0.9899598393574297, 'class_Many_specificity': 0.9964580873671782, 'class_None_specificity': 0.9822804314329738, 'class_Few_f1': 0.9833076101151609, 'class_Many_f1': 0.9982259018332348, 'class_None_f1': 0.9855365451221144, 'auc_normal_vs_abnormal': 0.9985574089202801, 'auc_few_vs_many': 0.9994811075994151}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9782234957020057, 'val_auc': 0.9986423915735593, 'val_f1': 0.9783972401699138, 'avg_sensitivity': 0.9874502684145154, 'avg_specificity': 0.9883588007671399, 'class_Few_sensitivity': 0.9735364875701684, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9888143176733781, 'class_Few_specificity': 0.9899598393574297, 'class_Many_specificity': 0.9982290436835891, 'class_None_specificity': 0.9768875192604006, 'class_Few_f1': 0.981679478210807, 'class_Many_f1': 0.9991137370753324, 'class_None_f1': 0.9828147358379394, 'auc_normal_vs_abnormal': 0.99871252624068, 'auc_few_vs_many': 0.9999371039514443}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.974785100286533, 'val_auc': 0.9979211125808721, 'val_f1': 0.975005391488167, 'avg_sensitivity': 0.9844034841395523, 'avg_specificity': 0.9861217646092509, 'class_Few_sensitivity': 0.971107544141252, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9821029082774049, 'class_Few_specificity': 0.9859719438877755, 'class_Many_specificity': 0.9970466627288836, 'class_None_specificity': 0.975346687211094, 'class_Few_f1': 0.9784832950094591, 'class_Many_f1': 0.9985211475894705, 'class_None_f1': 0.9787131380511462, 'auc_normal_vs_abnormal': 0.9979541748965023, 'auc_few_vs_many': 0.9992746018026917}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9283667621776505, 'val_auc': 0.9658066534542527, 'val_f1': 0.9280219174340245, 'avg_sensitivity': 0.8796462405186793, 'avg_specificity': 0.939104629201863, 'class_Few_sensitivity': 0.9582664526484751, 'class_Many_sensitivity': 0.8235294117647058, 'class_None_sensitivity': 0.8571428571428571, 'class_Few_specificity': 0.8597194388777555, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9575944487278335, 'class_Few_f1': 0.9063219916131429, 'class_Many_f1': 0.9032258064516129, 'class_None_f1': 0.9045884923525127, 'auc_normal_vs_abnormal': 0.9675384128207953, 'auc_few_vs_many': 0.970603971925849}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9764908256880734, 'val_auc': 0.9982727396971179, 'val_f1': 0.9767042536212108, 'avg_sensitivity': 0.9847278629421755, 'avg_specificity': 0.9862327102181533, 'class_Few_sensitivity': 0.9743178170144462, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9798657718120806, 'class_Few_specificity': 0.9819277108433735, 'class_Many_specificity': 0.9952746603662138, 'class_None_specificity': 0.9814957594448728, 'class_Few_f1': 0.9781079624933889, 'class_Many_f1': 0.9976317347542925, 'class_None_f1': 0.9806800883286416, 'auc_normal_vs_abnormal': 0.9986477139639056, 'auc_few_vs_many': 0.9992761149403582}
# Average results across all folds:
# val_accuracy: 0.9676763886333166
# val_auc: 0.9917662046323679
# val_f1: 0.9677607519776095
# avg_sensitivity: 0.9649494714509771
# avg_specificity: 0.9778768048364535
# class_Few_sensitivity: 0.9707944974841707
# class_Many_sensitivity: 0.9647058823529411
# class_None_sensitivity: 0.9593480345158198
# class_Few_specificity: 0.9615077544647528
# class_Many_specificity: 0.9974016908291728
# class_None_specificity: 0.9747209692154349
# class_Few_f1: 0.9655800674883916
# class_Many_f1: 0.9793436655407886
# class_None_f1: 0.966466599938471
# auc_normal_vs_abnormal: 0.9922820473684327
# auc_few_vs_many: 0.9937145800439516
