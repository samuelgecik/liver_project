# %%
import os
import json
from metrics import *
from sklearn.metrics import make_scorer, cohen_kappa_score, balanced_accuracy_score
import numpy as np
from sklearn.model_selection import StratifiedKFold, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
# Load features and labels
X = np.load('../../features.npy')
y = np.load('../../labels.npy')

X.shape, y.shape
# Out:
# ((8724, 2048), (8724,))

# %%
# Count the number of samples in each class
print('Number of samples in each class:')
print(np.unique(y, return_counts=True))

# Define class names
class_names = ["Few", "Many", "None"]
print('Class names:')
print(class_names)
# Out:
# Number of samples in each class:
# (array([0, 1, 2]), array([6232,  256, 2236]))
# Class names:
# ['Few', 'Many', 'None']

# %%
os.makedirs('logs', exist_ok=True)
os.makedirs('figures', exist_ok=True)

# %%
def custom_scorer(y_true, y_pred):
    # If y_pred is probabilities, convert to class predictions
    if y_pred.ndim == 2:
        y_pred_class = np.argmax(y_pred, axis=1)
    else:
        y_pred_class = y_pred

    # Calculate metrics
    auc = roc_auc_score(y_true, y_pred, average='macro', multi_class='ovo')
    f1 = f1_score(y_true, y_pred_class, average='macro')
    kappa = cohen_kappa_score(y_true, y_pred_class)
    balanced_acc = balanced_accuracy_score(y_true, y_pred_class)
    
    return 0.3 * auc + 0.3 * f1 + 0.2 * kappa + 0.2 * balanced_acc

custom_score = make_scorer(custom_scorer, greater_is_better=True, needs_proba=True)
# Out:
# /home/samo/dev/liver/.venv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:610: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'class_weight': ['balanced', 'balanced_subsample', None]
}

# Initialize the Random Forest classifier
rf = RandomForestClassifier(random_state=42)

# Define the cross-validation strategy
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=rf, 
    param_distributions=param_grid,
    n_iter=100, 
    cv=cv, 
    verbose=2, 
    random_state=42, 
    n_jobs=-1,
    scoring=custom_score
)

# %%
# Fit RandomizedSearchCV
random_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.9s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.5s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.4s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.9s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.2s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.6s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  21.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.2s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.2s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  23.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  23.3s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  23.5s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  22.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  15.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.2s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.3s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  19.6s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.4s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  24.0s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  24.8s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  24.8s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  46.1s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  33.0s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  43.0s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.1s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  43.7s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.9s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  46.0s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.2s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.1s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.5min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.3min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  45.9s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  46.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  33.2s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.2s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.3s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  30.0s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  44.0s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  41.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.7s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  40.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  40.1s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.2s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  39.7s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.0min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  31.6s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  38.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  40.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  41.7s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  39.0s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  31.3s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  42.7s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  43.5s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  43.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  45.4s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  34.6s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  32.6s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  33.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  28.4s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  33.2s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  43.4s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  21.6s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  32.2s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.2s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  43.3s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  40.6s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  40.3s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  15.0s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  21.2s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.9min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  20.4s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.9min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  27.9s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  33.6s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.0min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  33.6s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  33.6s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  32.8s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.3s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  15.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.8s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  20.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  21.1s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  21.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.3s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  16.1s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  21.5s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.1s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.9s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  29.7s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  19.9s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.2min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.1s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.0s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.3s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.5s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  19.8s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.8s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  19.9s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.6min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.6min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.0s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  16.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  18.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.1s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.3s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.5s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  29.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  41.2s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  39.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  40.7s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  40.7s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  16.0s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  23.0s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  23.5s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  43.5s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  42.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  41.3s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.0s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  16.5s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.7s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  16.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.3s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  40.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.0s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  20.9s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  15.5s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  19.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  20.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  14.7s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  20.0s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  20.0s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.5s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  20.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.3s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.2s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.9s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.9s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  17.9s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.6min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  17.2s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  32.9s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  14.9s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  46.2s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.7s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  46.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  17.0s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  44.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.0s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  47.6s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.8s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.8s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  16.6s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.0s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  23.1s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.4s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  23.1s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  29.3s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.6s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  22.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  42.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  42.1s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  29.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  39.8s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.3s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  43.4s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  41.1s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  20.4s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  15.3s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  43.9s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  28.9s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  28.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  39.4s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  40.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  40.8s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=  41.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  40.9s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  39.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  38.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  40.1s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  43.4s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  43.4s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  18.9s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  30.6s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  41.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  31.4s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  14.8s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  19.6s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=  42.5s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  43.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  42.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  40.6s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  19.6s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=  41.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  15.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.9s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.0s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  20.8s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.3s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.2min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.6min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.6min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.1s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.5s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.5s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  15.4s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  20.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  27.9s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.2min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  28.1s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  20.9s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  23.7s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 2.0min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.6s
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 2.0min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.8s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.2s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  25.9s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.8s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  29.1s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  33.5s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  39.5s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  40.9s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  32.6s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  39.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  36.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  41.5s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  51.1s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  40.5s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  42.2s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  40.2s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  31.4s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  41.4s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  40.1s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  35.0s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  40.4s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  43.5s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  41.6s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.6s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  49.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.7s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.8s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  24.8s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  34.6s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  41.8s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  33.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  29.2s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 2.1min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 2.1min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  25.0s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  17.8s
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  42.4s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  23.3s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  24.2s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  23.4s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  21.5s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  21.6s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  15.7s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  22.1s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  23.3s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  22.2s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.5min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  20.7s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  20.5s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.6min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  19.3s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  21.0s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.9s
# ...
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 2.1min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time= 2.1min
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  17.1s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  23.1s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.9s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  22.8s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=  56.3s
# [CV] END class_weight=None, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.2min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.2min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  42.2s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  29.9s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  42.2s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  26.4s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  42.1s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  26.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.8s
# [CV] END class_weight=None, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=  42.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.2min
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.2min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  19.1s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  21.9s
# [CV] END class_weight=balanced, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.9s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  41.8s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  37.5s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  41.7s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  43.0s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=  51.9s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  39.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  39.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  37.0s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  38.8s
# [CV] END class_weight=balanced, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=  49.7s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.3min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.9min
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.0min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.0s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  15.3s
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.6s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  26.0s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.8min
# [CV] END class_weight=balanced_subsample, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.0s
# [CV] END class_weight=None, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 2.4min
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.0s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  20.0s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  19.9s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  18.7s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.3s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  16.1s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END class_weight=balanced_subsample, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  26.2s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  21.4s
# [CV] END class_weight=None, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  17.6s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 2.2min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.3min
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.8s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  15.6s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  20.0s
# [CV] END class_weight=balanced, max_depth=30, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  18.1s
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.7min
# [CV] END class_weight=balanced, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.6min
# /home/samo/dev/liver/.venv/lib/python3.11/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Best parameters: {'n_estimators': 500, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_depth': 20, 'class_weight': None}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 17
#      14 X_train, X_val = X[train_index], X[val_index]
#      15 y_train, y_val = y[train_index], y[val_index]
# ---> 17 best_rf.fit(X_train, y_train)
#      18 y_pred = best_rf.predict(X_val)
#      19 y_prob = best_rf.predict_proba(X_val)
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File ~/dev/liver/.venv/lib/python3.11/site-packages/sklearn/tree/_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# # Get the best parameters
# best_params = random_search.best_params_
# print("Best parameters:", best_params)

# Load the best parameters from a json file
with open('random_forest_optimized_best_params.json', 'r') as f:
    best_params = json.load(f)

# Now, let's perform a final 10-fold cross-validation using the best model
best_rf = RandomForestClassifier(**best_params, random_state=42)

fold_results = []

for fold, (train_index, val_index) in enumerate(cv.split(X, y), 1):
    print(f"Fold {fold}")
    X_train, X_val = X[train_index], X[val_index]
    y_train, y_val = y[train_index], y[val_index]
    
    best_rf.fit(X_train, y_train)
    y_pred = best_rf.predict(X_val)
    y_prob = best_rf.predict_proba(X_val)
    
    # Calculate metrics
    accuracy, class_metrics, auc, f1, cm, avg_sensitivity, avg_specificity = calculate_metrics(y_val, y_pred, y_prob)
    
    # Calculate AUC for double dichotomy
    double_dichotomy_auc = calculate_double_dichotomy_auc(y_val, y_prob)

    # Log metrics for this fold
    metrics = {
        'fold': fold,
        'val_accuracy': accuracy,
        'val_auc': auc,
        'val_f1': f1,
        'avg_sensitivity': avg_sensitivity,
        'avg_specificity': avg_specificity,
        **{f'class_{class_names[i]}_sensitivity': metrics["sensitivity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_specificity': metrics["specificity"] for i, metrics in enumerate(class_metrics)},
        **{f'class_{class_names[i]}_f1': 2 * metrics["sensitivity"] * metrics["specificity"] / (metrics["sensitivity"] + metrics["specificity"]) for i, metrics in enumerate(class_metrics)},
        **double_dichotomy_auc
    }
    
    custom_log(metrics, model_name=f'random_forest_optimized_{fold}', log_dir='logs')
    print("Metrics for this fold:")
    print(metrics)

    # Plot confusion matrix for this fold
    plot_confusion_matrix(cm, class_names=class_names, epoch_num=0, model_name='random_forest_optimized', fold_num=fold)
    
    fold_results.append(metrics)

# Calculate and print average results across all folds
avg_results = {key: np.mean([fold[key] for fold in fold_results if key in fold]) 
               for key in fold_results[0].keys() if key != 'fold'}

print("Average results across all folds:")
for key, value in avg_results.items():
    print(f"{key}: {value}")

# Log average results
custom_log(avg_results, model_name='random_forest_optimized_average', log_dir='logs')
# Out:
# Fold 1
# Metrics for this fold:
# {'fold': 1, 'val_accuracy': 0.9879656160458453, 'val_auc': 0.9988192149439342, 'val_f1': 0.9879417164496996, 'avg_sensitivity': 0.9881672763326989, 'avg_specificity': 0.9893041171282024, 'class_Few_sensitivity': 0.9935846030473136, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.970917225950783, 'class_Few_specificity': 0.9738955823293173, 'class_Many_specificity': 0.999409681227863, 'class_None_specificity': 0.9946070878274268, 'class_Few_f1': 0.9836415764390248, 'class_Many_f1': 0.9997047534691467, 'class_None_f1': 0.9826193935684477, 'auc_normal_vs_abnormal': 0.9988090436844844, 'auc_few_vs_many': 1.0}
# Fold 2
# Metrics for this fold:
# {'fold': 2, 'val_accuracy': 0.9828080229226361, 'val_auc': 0.9986154802163035, 'val_f1': 0.9828477000936321, 'avg_sensitivity': 0.9867183103729338, 'avg_specificity': 0.9878179464568162, 'class_Few_sensitivity': 0.9847634322373697, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9753914988814317, 'class_Few_specificity': 0.9779116465863453, 'class_Many_specificity': 0.999409681227863, 'class_None_specificity': 0.9861325115562404, 'class_Few_f1': 0.9813255794682291, 'class_Many_f1': 0.9997047534691467, 'class_None_f1': 0.9807325971278144, 'auc_normal_vs_abnormal': 0.9987452732305422, 'auc_few_vs_many': 0.9998742079028884}
# Fold 3
# Metrics for this fold:
# {'fold': 3, 'val_accuracy': 0.9828080229226361, 'val_auc': 0.9987467116815683, 'val_f1': 0.9828061945943113, 'avg_sensitivity': 0.9848014765818852, 'avg_specificity': 0.9866589095073195, 'class_Few_sensitivity': 0.9879614767255217, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9664429530201343, 'class_Few_specificity': 0.9719438877755511, 'class_Many_specificity': 0.9988186650915535, 'class_None_specificity': 0.9892141756548536, 'class_Few_f1': 0.9798872293056091, 'class_Many_f1': 0.9994089834515367, 'class_None_f1': 0.9776959928931754, 'auc_normal_vs_abnormal': 0.9986280734773512, 'auc_few_vs_many': 0.999984565995802}
# Fold 4
# Metrics for this fold:
# {'fold': 4, 'val_accuracy': 0.9289398280802292, 'val_auc': 0.9584335486257506, 'val_f1': 0.9272371725231446, 'avg_sensitivity': 0.8346788153463632, 'avg_specificity': 0.9303196472616269, 'class_Few_sensitivity': 0.9767255216693419, 'class_Many_sensitivity': 0.7058823529411765, 'class_None_sensitivity': 0.8214285714285714, 'class_Few_specificity': 0.8156312625250501, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9753276792598303, 'class_Few_f1': 0.8889389405108558, 'class_Many_f1': 0.8275862068965517, 'class_None_f1': 0.8917870990482903, 'auc_normal_vs_abnormal': 0.9601363723978412, 'auc_few_vs_many': 0.936982658231832}
# Fold 5
# Metrics for this fold:
# {'fold': 5, 'val_accuracy': 0.9873853211009175, 'val_auc': 0.9984492304202983, 'val_f1': 0.98733918029759, 'avg_sensitivity': 0.9864634690816728, 'avg_specificity': 0.9877484752683312, 'class_Few_sensitivity': 0.9951845906902087, 'class_Many_sensitivity': 1.0, 'class_None_sensitivity': 0.9642058165548099, 'class_Few_specificity': 0.9678714859437751, 'class_Many_specificity': 1.0, 'class_None_specificity': 0.9953739398612182, 'class_Few_f1': 0.9813380270127379, 'class_Many_f1': 1.0, 'class_None_f1': 0.9795420056967619, 'auc_normal_vs_abnormal': 0.9984148585877926, 'auc_few_vs_many': 1.0}
# Average results across all folds:
# val_accuracy: 0.9739813622144528
# val_auc: 0.990612837177571
# val_f1: 0.9736343927916755
# avg_sensitivity: 0.9561658695431108
# avg_specificity: 0.9763698191244593
# class_Few_sensitivity: 0.987643924873951
# class_Many_sensitivity: 0.9411764705882353
# class_None_sensitivity: 0.9396772131671461
# class_Few_specificity: 0.9414507730320079
# class_Many_specificity: 0.9995276055094559
# class_None_specificity: 0.9881310788319139
# class_Few_f1: 0.9630262705472912
# class_Many_f1: 0.9652809394572763
# class_None_f1: 0.9624754176668979
# auc_normal_vs_abnormal: 0.9909467242756025
# auc_few_vs_many: 0.9873682864261045
